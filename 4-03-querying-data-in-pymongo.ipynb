# %% [markdown]
# # Querying Data in _pymongo_

# %% [markdown]
# In this session we will expand upon the work in the previous ("3-02: Connecting to a MongoDB Database") by covering different types of queries and data manipulations. As such, we will begin by re-establishing our connection to the sample database created previously:

# %%
from pymongo import MongoClient
import urllib

# final version
con_str = "mongodb+srv://michaelm:" + urllib.parse.quote_plus("B!gD@t@T3(h") + "@cluster0.m2kzp.mongodb.net/sample_analytics?retryWrites=true&w=majority"

client = MongoClient(con_str)

db = client.sample_analytics # database
collection = db.customers # select the customers collection

# %% [markdown]
# In the last session we randomly selected a record from the collection. Here we'll re-run this to demonstrate after other queries we may run:

# %%
record = collection.find_one()
record
# Out:
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9508/1101801884.py in <module>
# ----> 1 record = collection.find_one()
#       2 record
#
# C:\Python\Python310\lib\site-packages\pymongo\collection.py in find_one(self, filter, *args, **kwargs)
#    1112
#    1113         cursor = self.find(filter, *args, **kwargs)
# -> 1114         for result in cursor.limit(-1):
#    1115             return result
#    1116         return None
#
# C:\Python\Python310\lib\site-packages\pymongo\cursor.py in next(self)
#    1157         if self.__empty:
#    1158             raise StopIteration
# -> 1159         if len(self.__data) or self._refresh():
#    1160             return self.__data.popleft()
#    1161         else:
#
# C:\Python\Python310\lib\site-packages\pymongo\cursor.py in _refresh(self)
#    1078                                   self.__allow_disk_use,
#    1079                                   self.__exhaust)
# -> 1080             self.__send_message(q)
#    1081         elif self.__id:  # Get More
#    1082             if self.__limit:
#
# C:\Python\Python310\lib\site-packages\pymongo\cursor.py in __send_message(self, operation)
#     969
#     970         try:
# --> 971             response = client._run_operation(
#     972                 operation, self._unpack_response, address=self.__address)
#     973         except OperationFailure as exc:
#
# C:\Python\Python310\lib\site-packages\pymongo\mongo_client.py in _run_operation(self, operation, unpack_res, address)
#    1213                 unpack_res)
#    1214
# -> 1215         return self._retryable_read(
#    1216             _cmd, operation.read_preference, operation.session,
#    1217             address=address, retryable=isinstance(operation, message._Query))
#
# C:\Python\Python310\lib\site-packages\pymongo\mongo_client.py in _retryable_read(self, func, read_pref, session, address, retryable)
#    1305                 server = self._select_server(
#    1306                     read_pref, session, address=address)
# -> 1307                 with self._secondaryok_for_server(read_pref, server, session) as (
#    1308                             sock_info, secondary_ok):
#    1309                     if retrying and not retryable:
#
# C:\Python\Python310\lib\contextlib.py in __enter__(self)
#     133         del self.args, self.kwds, self.func
#     134         try:
# --> 135             return next(self.gen)
#     136         except StopIteration:
#     137             raise RuntimeError("generator didn't yield") from None
#
# C:\Python\Python310\lib\site-packages\pymongo\mongo_client.py in _secondaryok_for_server(self, read_preference, server, session)
#    1160         single = topology.description.topology_type == TOPOLOGY_TYPE.Single
#    1161
# -> 1162         with self._get_socket(server, session) as sock_info:
#    1163             secondary_ok = (single and not sock_info.is_mongos) or (
#    1164                 read_preference != ReadPreference.PRIMARY)
#
# C:\Python\Python310\lib\contextlib.py in __enter__(self)
#     133         del self.args, self.kwds, self.func
#     134         try:
# --> 135             return next(self.gen)
#     136         except StopIteration:
#     137             raise RuntimeError("generator didn't yield") from None
#
# C:\Python\Python310\lib\site-packages\pymongo\mongo_client.py in _get_socket(self, server, session)
#    1097                 yield session._pinned_connection
#    1098                 return
# -> 1099             with server.get_socket(
#    1100                     self.__all_credentials, handler=err_handler) as sock_info:
#    1101                 # Pin this session to the selected server or connection.
#
# C:\Python\Python310\lib\contextlib.py in __enter__(self)
#     133         del self.args, self.kwds, self.func
#     134         try:
# --> 135             return next(self.gen)
#     136         except StopIteration:
#     137             raise RuntimeError("generator didn't yield") from None
#
# C:\Python\Python310\lib\site-packages\pymongo\pool.py in get_socket(self, all_credentials, handler)
#    1369             listeners.publish_connection_check_out_started(self.address)
#    1370
# -> 1371         sock_info = self._get_socket(all_credentials)
#    1372         if self.enabled_for_cmap:
#    1373             listeners.publish_connection_checked_out(
#
# C:\Python\Python310\lib\site-packages\pymongo\pool.py in _get_socket(self, all_credentials)
#    1481                 else:  # We need to create a new connection
#    1482                     try:
# -> 1483                         sock_info = self.connect(all_credentials)
#    1484                     finally:
#    1485                         with self._max_connecting_cond:
#
# C:\Python\Python310\lib\site-packages\pymongo\pool.py in connect(self, all_credentials)
#    1335                 self.is_writable = sock_info.is_writable
#    1336
# -> 1337             sock_info.check_auth(all_credentials)
#    1338         except BaseException:
#    1339             sock_info.close_socket(ConnectionClosedReason.ERROR)
#
# C:\Python\Python310\lib\site-packages\pymongo\pool.py in check_auth(self, all_credentials)
#     812             for credentials in all_credentials.values():
#     813                 if credentials not in self.authset:
# --> 814                     self.authenticate(credentials)
#     815
#     816         # CMAP spec says to publish the ready event only after authenticating
#
# C:\Python\Python310\lib\site-packages\pymongo\pool.py in authenticate(self, credentials)
#     829           - `credentials`: A MongoCredential.
#     830         """
# --> 831         auth.authenticate(credentials, self)
#     832         self.authset.add(credentials)
#     833         # negotiated_mechanisms are no longer needed.
#
# C:\Python\Python310\lib\site-packages\pymongo\auth.py in authenticate(credentials, sock_info)
#     546     mechanism = credentials.mechanism
#     547     auth_func = _AUTH_MAP.get(mechanism)
# --> 548     auth_func(credentials, sock_info)
#     549
#
# C:\Python\Python310\lib\site-packages\pymongo\auth.py in _authenticate_default(credentials, sock_info)
#     467             return _authenticate_scram(credentials, sock_info, 'SCRAM-SHA-256')
#     468         else:
# --> 469             return _authenticate_scram(credentials, sock_info, 'SCRAM-SHA-1')
#     470     else:
#     471         return _authenticate_scram(credentials, sock_info, 'SCRAM-SHA-1')
#
# C:\Python\Python310\lib\site-packages\pymongo\auth.py in _authenticate_scram(credentials, sock_info, mechanism)
#     241                ('conversationId', res['conversationId']),
#     242                ('payload', Binary(client_final))])
# --> 243     res = sock_info.command(source, cmd)
#     244
#     245     parsed = _parse_scram_response(res['payload'])
#
# C:\Python\Python310\lib\site-packages\pymongo\pool.py in command(self, dbname, spec, secondary_ok, read_preference, codec_options, check, allowable_errors, check_keys, read_concern, write_concern, parse_write_concern_error, collation, session, client, retryable_write, publish_events, user_fields, exhaust_allowed)
#     717             self._raise_if_not_writable(unacknowledged)
#     718         try:
# --> 719             return command(self, dbname, spec, secondary_ok,
#     720                            self.is_mongos, read_preference, codec_options,
#     721                            session, client, check, allowable_errors,
#
# C:\Python\Python310\lib\site-packages\pymongo\network.py in command(sock_info, dbname, spec, secondary_ok, is_mongos, read_preference, codec_options, session, client, check, allowable_errors, address, check_keys, listeners, max_bson_size, read_concern, parse_write_concern_error, collation, compression_ctx, use_op_msg, unacknowledged, user_fields, exhaust_allowed)
#     156                 client._process_response(response_doc, session)
#     157             if check:
# --> 158                 helpers._check_command_response(
#     159                     response_doc, sock_info.max_wire_version, allowable_errors,
#     160                     parse_write_concern_error=parse_write_concern_error)
#
# C:\Python\Python310\lib\site-packages\pymongo\helpers.py in _check_command_response(response, max_wire_version, allowable_errors, parse_write_concern_error)
#     168         raise CursorNotFound(errmsg, code, response, max_wire_version)
#     169
# --> 170     raise OperationFailure(errmsg, code, response, max_wire_version)
#     171
#     172
#
# OperationFailure: bad auth : Authentication failed., full error: {'ok': 0, 'errmsg': 'bad auth : Authentication failed.', 'code': 8000, 'codeName': 'AtlasError'}

# %% [markdown]
# Firstly we may note that the database is returning a dictionary. We can use this to extract the elements we want:

# %%
print(record['_id'])
print(record['accounts'][0:3])
# Out:
# 5ca4bbcea2dd94ee58162a68
# [371138, 324287, 276528]

# %% [markdown]
# We can use the "ObjectId" above to demonstrate querying by ID:

# %%
collection.find_one({"_id": record['_id']})
# Out:
# {'_id': ObjectId('5ca4bbcea2dd94ee58162a68'),
#  'username': 'fmiller',
#  'name': 'Elizabeth Ray',
#  'address': '9286 Bethany Glens\nVasqueztown, CO 22939',
#  'birthdate': datetime.datetime(1977, 3, 2, 2, 20, 31),
#  'email': 'arroyocolton@gmail.com',
#  'active': True,
#  'accounts': [371138, 324287, 276528, 332179, 422649, 387979],
#  'tier_and_details': {'0df078f33aa74a2e9696e0520c1a828a': {'tier': 'Bronze',
#    'id': '0df078f33aa74a2e9696e0520c1a828a',
#    'active': True,
#    'benefits': ['sports tickets']},
#   '699456451cc24f028d2aa99d7534c219': {'tier': 'Bronze',
#    'benefits': ['24 hour dedicated line', 'concierge services'],
#    'active': True,
#    'id': '699456451cc24f028d2aa99d7534c219'}}}

# %% [markdown]
# Alternatively we can use _find()_ to search the whole collection:

# %%
count = 0

for doc in collection.find():
    if count < 5:
        print(doc)
        count += 1
    else:
        break
# Out:
# {'_id': ObjectId('5ca4bbcea2dd94ee58162a68'), 'username': 'fmiller', 'name': 'Elizabeth Ray', 'address': '9286 Bethany Glens\nVasqueztown, CO 22939', 'birthdate': datetime.datetime(1977, 3, 2, 2, 20, 31), 'email': 'arroyocolton@gmail.com', 'active': True, 'accounts': [371138, 324287, 276528, 332179, 422649, 387979], 'tier_and_details': {'0df078f33aa74a2e9696e0520c1a828a': {'tier': 'Bronze', 'id': '0df078f33aa74a2e9696e0520c1a828a', 'active': True, 'benefits': ['sports tickets']}, '699456451cc24f028d2aa99d7534c219': {'tier': 'Bronze', 'benefits': ['24 hour dedicated line', 'concierge services'], 'active': True, 'id': '699456451cc24f028d2aa99d7534c219'}}}
# {'_id': ObjectId('5ca4bbcea2dd94ee58162a69'), 'username': 'valenciajennifer', 'name': 'Lindsay Cowan', 'address': 'Unit 1047 Box 4089\nDPO AA 57348', 'birthdate': datetime.datetime(1994, 2, 19, 23, 46, 27), 'email': 'cooperalexis@hotmail.com', 'accounts': [116508], 'tier_and_details': {'c06d340a4bad42c59e3b6665571d2907': {'tier': 'Platinum', 'benefits': ['dedicated account representative'], 'active': True, 'id': 'c06d340a4bad42c59e3b6665571d2907'}, '5d6a79083c26402bbef823a55d2f4208': {'tier': 'Bronze', 'benefits': ['car rental insurance', 'concierge services'], 'active': True, 'id': '5d6a79083c26402bbef823a55d2f4208'}, 'b754ec2d455143bcb0f0d7bd46de6e06': {'tier': 'Gold', 'benefits': ['airline lounge access'], 'active': True, 'id': 'b754ec2d455143bcb0f0d7bd46de6e06'}}}
# {'_id': ObjectId('5ca4bbcea2dd94ee58162a6a'), 'username': 'hillrachel', 'name': 'Katherine David', 'address': '55711 Janet Plaza Apt. 865\nChristinachester, CT 62716', 'birthdate': datetime.datetime(1988, 6, 20, 22, 15, 34), 'email': 'timothy78@hotmail.com', 'accounts': [462501, 228290, 968786, 515844, 377292], 'tier_and_details': {}}
# {'_id': ObjectId('5ca4bbcea2dd94ee58162a6b'), 'username': 'serranobrian', 'name': 'Leslie Martinez', 'address': 'Unit 2676 Box 9352\nDPO AA 38560', 'birthdate': datetime.datetime(1974, 11, 26, 14, 30, 20), 'email': 'tcrawford@gmail.com', 'accounts': [170945, 951849], 'tier_and_details': {'a15baf69a759423297f11ce6c7b0bc9a': {'tier': 'Platinum', 'benefits': ['airline lounge access'], 'active': True, 'id': 'a15baf69a759423297f11ce6c7b0bc9a'}}}
# {'_id': ObjectId('5ca4bbcea2dd94ee58162a6c'), 'username': 'charleshudson', 'name': 'Brad Cardenas', 'address': '2765 Powers Meadow\nHeatherfurt, CT 53165', 'birthdate': datetime.datetime(1977, 5, 6, 21, 57, 35), 'email': 'dustin37@yahoo.com', 'accounts': [721914, 817222, 973067, 260799, 87389], 'tier_and_details': {}}

# %% [markdown]
# We can also use _find()_ to return all results that meet some criteria, for instance:

# %%
import datetime

count = 0

# midnight on the 13th June 1981
date_cutoff = datetime.datetime(1981, 6, 13, 0, 0, 0)

for doc in collection.find({"birthdate": {"$lt": date_cutoff}}):
    if count < 5:
        print(doc)
        count += 1
    else:
        break
# Out:
# {'_id': ObjectId('5ca4bbcea2dd94ee58162a68'), 'username': 'fmiller', 'name': 'Elizabeth Ray', 'address': '9286 Bethany Glens\nVasqueztown, CO 22939', 'birthdate': datetime.datetime(1977, 3, 2, 2, 20, 31), 'email': 'arroyocolton@gmail.com', 'active': True, 'accounts': [371138, 324287, 276528, 332179, 422649, 387979], 'tier_and_details': {'0df078f33aa74a2e9696e0520c1a828a': {'tier': 'Bronze', 'id': '0df078f33aa74a2e9696e0520c1a828a', 'active': True, 'benefits': ['sports tickets']}, '699456451cc24f028d2aa99d7534c219': {'tier': 'Bronze', 'benefits': ['24 hour dedicated line', 'concierge services'], 'active': True, 'id': '699456451cc24f028d2aa99d7534c219'}}}
# {'_id': ObjectId('5ca4bbcea2dd94ee58162a6b'), 'username': 'serranobrian', 'name': 'Leslie Martinez', 'address': 'Unit 2676 Box 9352\nDPO AA 38560', 'birthdate': datetime.datetime(1974, 11, 26, 14, 30, 20), 'email': 'tcrawford@gmail.com', 'accounts': [170945, 951849], 'tier_and_details': {'a15baf69a759423297f11ce6c7b0bc9a': {'tier': 'Platinum', 'benefits': ['airline lounge access'], 'active': True, 'id': 'a15baf69a759423297f11ce6c7b0bc9a'}}}
# {'_id': ObjectId('5ca4bbcea2dd94ee58162a6c'), 'username': 'charleshudson', 'name': 'Brad Cardenas', 'address': '2765 Powers Meadow\nHeatherfurt, CT 53165', 'birthdate': datetime.datetime(1977, 5, 6, 21, 57, 35), 'email': 'dustin37@yahoo.com', 'accounts': [721914, 817222, 973067, 260799, 87389], 'tier_and_details': {}}
# {'_id': ObjectId('5ca4bbcea2dd94ee58162a6e'), 'username': 'hmyers', 'name': 'Dana Clarke', 'address': '50047 Smith Point Suite 162\nWilkinsstad, PA 04106', 'birthdate': datetime.datetime(1969, 6, 21, 2, 39, 20), 'email': 'vcarter@hotmail.com', 'accounts': [627629, 55958, 771641], 'tier_and_details': {'4c207e65857742f89d8155139b24c0f0': {'tier': 'Silver', 'benefits': ['car rental insurance', 'travel insurance'], 'active': True, 'id': '4c207e65857742f89d8155139b24c0f0'}, 'c04ee1d7093449148a3cc3bbca398529': {'tier': 'Platinum', 'benefits': ['24 hour dedicated line', 'dedicated account representative'], 'active': True, 'id': 'c04ee1d7093449148a3cc3bbca398529'}, '1e64a51089c54d08911baf77be6b3713': {'tier': 'Gold', 'benefits': ['concert tickets', 'dedicated account representative'], 'active': True, 'id': '1e64a51089c54d08911baf77be6b3713'}}}
# {'_id': ObjectId('5ca4bbcea2dd94ee58162a71'), 'username': 'glopez', 'name': 'Jennifer Lawrence', 'address': '4140 Pamela Hollow Apt. 849\nEast Elizabeth, TN 29566', 'birthdate': datetime.datetime(1972, 11, 10, 11, 1, 8), 'email': 'scott50@yahoo.com', 'accounts': [344885, 839927, 853542], 'tier_and_details': {}}

# %% [markdown]
# The code here returns the first 5 people who are younger than me. Note we first create a "date_cutoff" using _datetime.datetime_ (see [here](https://docs.python.org/3/library/datetime.html#examples-of-usage-datetime) for more details). After this we use the code "\{"\\$lt": date_cutoff\}" to apply the filter (where "\\$lt" represents "less than"; we could use "\\$gt" to achieve the opposite result). You can see the full list of operators [here](https://docs.mongodb.com/manual/reference/operator/query/).
#
# We can also filter based on nested elements in the dictionary:

# %%
count = 0

for doc in collection.find():
    if count < 5:
        if len(doc['accounts']) > 3:
            print(doc)
            count += 1
    else:
        break
# Out:
# {'_id': ObjectId('5ca4bbcea2dd94ee58162a68'), 'username': 'fmiller', 'name': 'Elizabeth Ray', 'address': '9286 Bethany Glens\nVasqueztown, CO 22939', 'birthdate': datetime.datetime(1977, 3, 2, 2, 20, 31), 'email': 'arroyocolton@gmail.com', 'active': True, 'accounts': [371138, 324287, 276528, 332179, 422649, 387979], 'tier_and_details': {'0df078f33aa74a2e9696e0520c1a828a': {'tier': 'Bronze', 'id': '0df078f33aa74a2e9696e0520c1a828a', 'active': True, 'benefits': ['sports tickets']}, '699456451cc24f028d2aa99d7534c219': {'tier': 'Bronze', 'benefits': ['24 hour dedicated line', 'concierge services'], 'active': True, 'id': '699456451cc24f028d2aa99d7534c219'}}}
# {'_id': ObjectId('5ca4bbcea2dd94ee58162a6a'), 'username': 'hillrachel', 'name': 'Katherine David', 'address': '55711 Janet Plaza Apt. 865\nChristinachester, CT 62716', 'birthdate': datetime.datetime(1988, 6, 20, 22, 15, 34), 'email': 'timothy78@hotmail.com', 'accounts': [462501, 228290, 968786, 515844, 377292], 'tier_and_details': {}}
# {'_id': ObjectId('5ca4bbcea2dd94ee58162a6c'), 'username': 'charleshudson', 'name': 'Brad Cardenas', 'address': '2765 Powers Meadow\nHeatherfurt, CT 53165', 'birthdate': datetime.datetime(1977, 5, 6, 21, 57, 35), 'email': 'dustin37@yahoo.com', 'accounts': [721914, 817222, 973067, 260799, 87389], 'tier_and_details': {}}
# {'_id': ObjectId('5ca4bbcea2dd94ee58162a6f'), 'username': 'andrewhamilton', 'name': 'Gary Nichols', 'address': '633 Miller Turnpike\nJonathanland, OR 62874', 'birthdate': datetime.datetime(1993, 2, 25, 17, 37, 29), 'email': 'laura34@yahoo.com', 'accounts': [385397, 337979, 325377, 440243, 586395, 86702], 'tier_and_details': {}}
# {'_id': ObjectId('5ca4bbcea2dd94ee58162a75'), 'username': 'nelsonmaria', 'name': 'John Vega', 'address': '86636 Maria Viaduct\nKennethhaven, SD 21876', 'birthdate': datetime.datetime(1983, 9, 21, 3, 22, 18), 'email': 'ryanpena@yahoo.com', 'accounts': [88112, 567199, 436071, 226641], 'tier_and_details': {}}

# %% [markdown]
# We may also want to use logical operators (e.g. "AND", "OR", "NOT", etc.). Again we use the \\$ operator to do this:

# %%
query = {
    '$and':
        [
            {"birthdate": {"$lt": date_cutoff}}, 
            {'username': 'fmiller'}
        ]
}

for doc in collection.find(query):
    print(doc)
# Out:
# {'_id': ObjectId('5ca4bbcea2dd94ee58162a68'), 'username': 'fmiller', 'name': 'Elizabeth Ray', 'address': '9286 Bethany Glens\nVasqueztown, CO 22939', 'birthdate': datetime.datetime(1977, 3, 2, 2, 20, 31), 'email': 'arroyocolton@gmail.com', 'active': True, 'accounts': [371138, 324287, 276528, 332179, 422649, 387979], 'tier_and_details': {'0df078f33aa74a2e9696e0520c1a828a': {'tier': 'Bronze', 'id': '0df078f33aa74a2e9696e0520c1a828a', 'active': True, 'benefits': ['sports tickets']}, '699456451cc24f028d2aa99d7534c219': {'tier': 'Bronze', 'benefits': ['24 hour dedicated line', 'concierge services'], 'active': True, 'id': '699456451cc24f028d2aa99d7534c219'}}}

# %% [markdown]
# These queries can be a little clunky but the idea is that it is a dictionary where the logical operator is the key, and the conditions are a list inside this.

# %% [markdown]
# We can also get MongoDB to provide a sort order for our results (the SQL equivalent would be ORDER BY):

# %%
count = 0

for doc in collection.find({"birthdate": {"$lt": date_cutoff}}).sort("birthdate"):
    if count < 5:
        print(doc)
        count += 1
    else:
        break
# Out:
# {'_id': ObjectId('5ca4bbcea2dd94ee58162c23'), 'username': 'amanda70', 'name': 'Christopher Watson', 'address': '98287 Ryan Unions Suite 404\nPort Robertside, MD 88317', 'birthdate': datetime.datetime(1966, 7, 29, 17, 22, 6), 'email': 'srobinson@yahoo.com', 'accounts': [765127, 460206, 344075, 313926, 322023], 'tier_and_details': {'5cb805661d8f4fad9290fbd0976bb95a': {'tier': 'Silver', 'benefits': ['dedicated account representative'], 'active': True, 'id': '5cb805661d8f4fad9290fbd0976bb95a'}, '545c5449ab1a4df0953c60d6ecc38fd5': {'tier': 'Silver', 'benefits': ['concert tickets', 'dedicated account representative'], 'active': True, 'id': '545c5449ab1a4df0953c60d6ecc38fd5'}}}
# {'_id': ObjectId('5ca4bbcea2dd94ee58162b92'), 'username': 'lisaroberts', 'name': 'Daniel Turner', 'address': '5498 Sandra Drive Suite 397\nWest Nancy, AZ 71732', 'birthdate': datetime.datetime(1966, 7, 30, 1, 15, 43), 'email': 'gmccarthy@yahoo.com', 'accounts': [576646], 'tier_and_details': {}}
# {'_id': ObjectId('5ca4bbcea2dd94ee58162aea'), 'username': 'markwells', 'name': 'Betty Clayton', 'address': '353 David Keys\nMadisonland, AR 76871', 'birthdate': datetime.datetime(1966, 8, 6, 0, 13, 47), 'email': 'egreen@yahoo.com', 'accounts': [377923], 'tier_and_details': {'76a2eef9b7de475bb3f8df7d1db99498': {'tier': 'Gold', 'benefits': ['concert tickets'], 'active': True, 'id': '76a2eef9b7de475bb3f8df7d1db99498'}}}
# {'_id': ObjectId('5ca4bbcea2dd94ee58162c44'), 'username': 'michael26', 'name': 'Jessica Gay', 'address': '332 Kaufman Mountains\nJeremyview, PA 16016', 'birthdate': datetime.datetime(1966, 8, 6, 16, 40, 12), 'email': 'maldonadojaime@yahoo.com', 'accounts': [265053, 86494, 619619, 428949, 275187], 'tier_and_details': {}}
# {'_id': ObjectId('5ca4bbcea2dd94ee58162b4e'), 'username': 'davidestrada', 'name': 'Angela Ortiz', 'address': '12948 Perez Village\nEast Kayla, NJ 25955', 'birthdate': datetime.datetime(1966, 8, 17, 5, 29, 22), 'email': 'mitchelldeborah@gmail.com', 'accounts': [236337, 533756], 'tier_and_details': {'55429058eda14f3ebe9cf7b852fbc1d1': {'tier': 'Bronze', 'benefits': ['concierge services', 'financial planning assistance'], 'active': True, 'id': '55429058eda14f3ebe9cf7b852fbc1d1'}, '970f0c15c509422e9c0ea73657847354': {'tier': 'Gold', 'benefits': ['airline lounge access', 'dedicated account representative'], 'active': True, 'id': '970f0c15c509422e9c0ea73657847354'}, '2b558fe1fa70429ba01e2ac2307ad495': {'tier': 'Silver', 'benefits': ['concierge services'], 'active': True, 'id': '2b558fe1fa70429ba01e2ac2307ad495'}}}

# %% [markdown]
# If we wish to search in descending order we need to add a "-1" to the _sort()_ command:

# %%
count = 0

for doc in collection.find({"birthdate": {"$lt": date_cutoff}}).sort("birthdate", -1):
    if count < 5:
        print(doc)
        count += 1
    else:
        break
# Out:
# {'_id': ObjectId('5ca4bbcea2dd94ee58162b79'), 'username': 'peter77', 'name': 'Jacqueline Dixon', 'address': '0960 Evans Mountain Apt. 236\nSouth Daniel, NC 56886', 'birthdate': datetime.datetime(1981, 4, 21, 12, 21, 33), 'email': 'cindyarmstrong@gmail.com', 'accounts': [514695, 587785, 572301, 198855, 505260], 'tier_and_details': {'f2e43dbe067a4a3db9132ecd41e4e188': {'tier': 'Silver', 'benefits': ['concierge services'], 'active': True, 'id': 'f2e43dbe067a4a3db9132ecd41e4e188'}, '7477f5bf4451493ea12bbc39115d83e6': {'tier': 'Platinum', 'benefits': ['concierge services', 'dedicated account representative'], 'active': True, 'id': '7477f5bf4451493ea12bbc39115d83e6'}}}
# {'_id': ObjectId('5ca4bbcea2dd94ee58162b1b'), 'username': 'cody34', 'name': 'Julie Erickson DDS', 'address': '4907 Morris Garden Apt. 647\nEmilystad, TX 73479', 'birthdate': datetime.datetime(1981, 4, 17, 17, 52, 49), 'email': 'sgreene@gmail.com', 'accounts': [103536, 971879], 'tier_and_details': {'86ee9babe3b14df28efd8027233d0013': {'tier': 'Silver', 'benefits': ['concert tickets', 'shopping discounts'], 'active': True, 'id': '86ee9babe3b14df28efd8027233d0013'}}}
# {'_id': ObjectId('5ca4bbcea2dd94ee58162b22'), 'username': 'steven28', 'name': 'Brian Brown', 'address': '063 Holly Greens\nLutzville, CT 20919', 'birthdate': datetime.datetime(1981, 3, 4, 0, 11, 19), 'email': 'garyriddle@hotmail.com', 'accounts': [795040], 'tier_and_details': {}}
# {'_id': ObjectId('5ca4bbcea2dd94ee58162c3a'), 'username': 'christinadavies', 'name': 'Ronald Ballard', 'address': '11323 Jessica Fall\nNorth Christinashire, AL 08240', 'birthdate': datetime.datetime(1981, 2, 16, 20, 40, 12), 'email': 'brianjones@gmail.com', 'accounts': [214649, 557547, 639934, 659017], 'tier_and_details': {}}
# {'_id': ObjectId('5ca4bbcea2dd94ee58162c35'), 'username': 'leeryan', 'name': 'Jennifer Mccormick', 'address': '434 David Skyway\nJuanside, OK 84356', 'birthdate': datetime.datetime(1981, 1, 10, 21, 24, 47), 'email': 'jessica27@hotmail.com', 'accounts': [182387, 618428], 'tier_and_details': {'ad3ac75296f348d08eacfb30149fc6e5': {'tier': 'Bronze', 'benefits': ['concert tickets', 'sports tickets'], 'active': True, 'id': 'ad3ac75296f348d08eacfb30149fc6e5'}, '10427cb061044a278c0eb394ef2ad11e': {'tier': 'Gold', 'benefits': ['car rental insurance', 'concierge services'], 'active': True, 'id': '10427cb061044a278c0eb394ef2ad11e'}, '6e93c7288f104b1ba05ad7ddadef3d4b': {'tier': 'Platinum', 'benefits': ['travel insurance', 'dedicated account representative'], 'active': True, 'id': '6e93c7288f104b1ba05ad7ddadef3d4b'}}}

# %% [markdown]
# ## Joining Data

# %% [markdown]
# Unlike relational databases, joining collections/tables is not implicit. There is no declared schema (this is NoSQL after all) so no defined relationship between collections like there would be for tables in the relational model. However, this does not mean it is impossible! We just need to inject the schema on _read_ rather than _write._
#
# The "best" way to do this is probably via ["aggregation pipelines"](https://docs.mongodb.com/manual/aggregation/), but these are fairly complicated so more than we will bother with here. Instead we can use more "Pythonic" solutions:

# %%
output = {}
first_query = []

for doc in collection.find({"birthdate": {"$lt": date_cutoff}}):
    try:
        # ignore any customer with no accounts or no username
        if doc['accounts'] and doc["username"]:  
            for acct in doc['accounts']:
                output[acct] = {"user": doc["username"], "limit": "Unknown"}
                first_query.append(acct)
    except:
        continue
    
second_collection = db.accounts

for doc in second_collection.find({"account_id": {"$in": first_query}}):
    output[doc["account_id"]]["limit"] = doc["limit"]
        
output
# Out:
# {371138: {'user': 'fmiller', 'limit': 9000},
#  324287: {'user': 'fmiller', 'limit': 10000},
#  276528: {'user': 'fmiller', 'limit': 10000},
#  332179: {'user': 'fmiller', 'limit': 10000},
#  422649: {'user': 'fmiller', 'limit': 10000},
#  387979: {'user': 'fmiller', 'limit': 10000},
#  170945: {'user': 'serranobrian', 'limit': 10000},
#  951849: {'user': 'serranobrian', 'limit': 10000},
#  721914: {'user': 'charleshudson', 'limit': 10000},
#  817222: {'user': 'charleshudson', 'limit': 10000},
#  973067: {'user': 'charleshudson', 'limit': 10000},
#  260799: {'user': 'charleshudson', 'limit': 10000},
#  87389: {'user': 'charleshudson', 'limit': 10000},
#  627629: {'user': 'hmyers', 'limit': 10000},
#  55958: {'user': 'hmyers', 'limit': 10000},
#  771641: {'user': 'hmyers', 'limit': 10000},
#  344885: {'user': 'glopez', 'limit': 10000},
#  839927: {'user': 'glopez', 'limit': 10000},
#  853542: {'user': 'glopez', 'limit': 10000},
#  987709: {'user': 'wesley20', 'limit': 10000},
#  571880: {'user': 'patricia44', 'limit': 10000},
#  883283: {'user': 'portermichael', 'limit': 10000},
#  980867: {'user': 'portermichael', 'limit': 10000},
#  164836: {'user': 'portermichael', 'limit': 10000},
#  200611: {'user': 'portermichael', 'limit': 10000},
#  528224: {'user': 'portermichael', 'limit': 10000},
#  931483: {'user': 'portermichael', 'limit': 10000},
#  550665: {'user': 'hunterdaniel', 'limit': 10000},
#  321695: {'user': 'hunterdaniel', 'limit': 10000},
#  66698: {'user': 'james75', 'limit': 10000},
#  859246: {'user': 'james75', 'limit': 10000},
#  183400: {'user': 'james75', 'limit': 10000},
#  460192: {'user': 'james75', 'limit': 10000},
#  928230: {'user': 'zsanders', 'limit': 10000},
#  120548: {'user': 'zsanders', 'limit': 10000},
#  667833: {'user': 'zsanders', 'limit': 10000},
#  810947: {'user': 'zsanders', 'limit': 10000},
#  836981: {'user': 'archersarah', 'limit': 10000},
#  602560: {'user': 'thomasboyd', 'limit': 10000},
#  986196: {'user': 'thomasboyd', 'limit': 10000},
#  51080: {'user': 'thomasboyd', 'limit': 10000},
#  690617: {'user': 'thomasboyd', 'limit': 10000},
#  225602: {'user': 'thomasboyd', 'limit': 10000},
#  388578: {'user': 'anthonyandrade', 'limit': 8000},
#  607567: {'user': 'rodriguezjeffrey', 'limit': 10000},
#  429282: {'user': 'rodriguezjeffrey', 'limit': 10000},
#  158557: {'user': 'paul82', 'limit': 10000},
#  87965: {'user': 'jessica94', 'limit': 10000},
#  312230: {'user': 'jessica94', 'limit': 10000},
#  759079: {'user': 'jessica94', 'limit': 10000},
#  986996: {'user': 'jessica94', 'limit': 10000},
#  344523: {'user': 'williammurphy', 'limit': 10000},
#  899684: {'user': 'glennkimberly', 'limit': 10000},
#  619693: {'user': 'glennkimberly', 'limit': 10000},
#  146756: {'user': 'abrown', 'limit': 10000},
#  120270: {'user': 'abrown', 'limit': 10000},
#  304730: {'user': 'mirandachad', 'limit': 10000},
#  588722: {'user': 'fgibson', 'limit': 10000},
#  171900: {'user': 'fgibson', 'limit': 10000},
#  775273: {'user': 'fgibson', 'limit': 10000},
#  212024: {'user': 'fgibson', 'limit': 10000},
#  725209: {'user': 'ashley97', 'limit': 10000},
#  738462: {'user': 'ashley97', 'limit': 10000},
#  57161: {'user': 'ashley97', 'limit': 10000},
#  436090: {'user': 'ashley97', 'limit': 10000},
#  714030: {'user': 'ashley97', 'limit': 10000},
#  351402: {'user': 'rwelch', 'limit': 10000},
#  813016: {'user': 'roger47', 'limit': 10000},
#  136137: {'user': 'roger47', 'limit': 10000},
#  831097: {'user': 'roger47', 'limit': 10000},
#  977774: {'user': 'gonzalezjonathan', 'limit': 10000},
#  895735: {'user': 'pgilbert', 'limit': 10000},
#  996263: {'user': 'pgilbert', 'limit': 10000},
#  62872: {'user': 'laurie54', 'limit': 10000},
#  327942: {'user': 'laurie54', 'limit': 10000},
#  720370: {'user': 'laurie54', 'limit': 10000},
#  893492: {'user': 'swiggins', 'limit': 9000},
#  904434: {'user': 'swiggins', 'limit': 10000},
#  918103: {'user': 'matthewharris', 'limit': 10000},
#  658755: {'user': 'matthewharris', 'limit': 10000},
#  304914: {'user': 'matthewharris', 'limit': 10000},
#  175894: {'user': 'matthewharris', 'limit': 10000},
#  849766: {'user': 'matthewharris', 'limit': 10000},
#  236908: {'user': 'salazarbilly', 'limit': 10000},
#  356905: {'user': 'salazarbilly', 'limit': 10000},
#  571311: {'user': 'salazarbilly', 'limit': 10000},
#  323636: {'user': 'salazarbilly', 'limit': 10000},
#  409325: {'user': 'salazarbilly', 'limit': 10000},
#  185130: {'user': 'oroberts', 'limit': 10000},
#  559866: {'user': 'oroberts', 'limit': 10000},
#  415928: {'user': 'rebecca82', 'limit': 10000},
#  525530: {'user': 'rebecca82', 'limit': 10000},
#  59819: {'user': 'ogonzalez', 'limit': 10000},
#  531283: {'user': 'ogonzalez', 'limit': 10000},
#  401811: {'user': 'nicole89', 'limit': 10000},
#  249109: {'user': 'nicole89', 'limit': 10000},
#  968012: {'user': 'nicole89', 'limit': 10000},
#  837602: {'user': 'emilybrooks', 'limit': 10000},
#  513374: {'user': 'emilybrooks', 'limit': 10000},
#  935752: {'user': 'emilybrooks', 'limit': 10000},
#  103346: {'user': 'emilybrooks', 'limit': 10000},
#  616805: {'user': 'emilybrooks', 'limit': 10000},
#  183917: {'user': 'emilybrooks', 'limit': 10000},
#  859697: {'user': 'julierobertson', 'limit': 10000},
#  116390: {'user': 'julierobertson', 'limit': 10000},
#  696619: {'user': 'julierobertson', 'limit': 10000},
#  714727: {'user': 'julierobertson', 'limit': 10000},
#  969957: {'user': 'julierobertson', 'limit': 10000},
#  571279: {'user': 'natalie11', 'limit': 10000},
#  226398: {'user': 'natalie11', 'limit': 10000},
#  694827: {'user': 'zriley', 'limit': 10000},
#  447644: {'user': 'zriley', 'limit': 10000},
#  469336: {'user': 'joshuagarcia', 'limit': 9000},
#  359211: {'user': 'joshuagarcia', 'limit': 10000},
#  626536: {'user': 'joshuagarcia', 'limit': 10000},
#  733789: {'user': 'joshuagarcia', 'limit': 10000},
#  851281: {'user': 'joshuagarcia', 'limit': 10000},
#  358133: {'user': 'pfranklin', 'limit': 10000},
#  54977: {'user': 'pfranklin', 'limit': 10000},
#  660732: {'user': 'laura78', 'limit': 10000},
#  167939: {'user': 'laura78', 'limit': 10000},
#  645476: {'user': 'spearsalec', 'limit': 10000},
#  165279: {'user': 'spearsalec', 'limit': 10000},
#  231223: {'user': 'spearsalec', 'limit': 10000},
#  621326: {'user': 'spearsalec', 'limit': 10000},
#  448325: {'user': 'spearsalec', 'limit': 10000},
#  666556: {'user': 'spearsalec', 'limit': 10000},
#  900264: {'user': 'ihill', 'limit': 10000},
#  306033: {'user': 'ihill', 'limit': 10000},
#  436026: {'user': 'ihill', 'limit': 10000},
#  627690: {'user': 'ihill', 'limit': 10000},
#  246735: {'user': 'ihill', 'limit': 10000},
#  707812: {'user': 'ebeasley', 'limit': 10000},
#  317282: {'user': 'ebeasley', 'limit': 10000},
#  721947: {'user': 'rivaslonnie', 'limit': 9000},
#  394038: {'user': 'rivaslonnie', 'limit': 10000},
#  958881: {'user': 'rivaslonnie', 'limit': 10000},
#  774823: {'user': 'waterskatherine', 'limit': 10000},
#  451764: {'user': 'waterskatherine', 'limit': 10000},
#  473748: {'user': 'waterskatherine', 'limit': 10000},
#  541512: {'user': 'waterskatherine', 'limit': 10000},
#  742134: {'user': 'waterskatherine', 'limit': 10000},
#  561206: {'user': 'christopherdean', 'limit': 10000},
#  287686: {'user': 'christopherdean', 'limit': 10000},
#  615233: {'user': 'christopherdean', 'limit': 10000},
#  774388: {'user': 'christopherdean', 'limit': 10000},
#  109139: {'user': 'christopherdean', 'limit': 10000},
#  453851: {'user': 'nsalinas', 'limit': 7000},
#  911207: {'user': 'nsalinas', 'limit': 10000},
#  593441: {'user': 'nsalinas', 'limit': 10000},
#  866159: {'user': 'ianjones', 'limit': 10000},
#  950569: {'user': 'ianjones', 'limit': 10000},
#  871955: {'user': 'ianjones', 'limit': 10000},
#  391838: {'user': 'ianjones', 'limit': 10000},
#  129238: {'user': 'ianjones', 'limit': 10000},
#  280867: {'user': 'ianjones', 'limit': 10000},
#  762459: {'user': 'maryfuller', 'limit': 10000},
#  590768: {'user': 'maryfuller', 'limit': 10000},
#  602559: {'user': 'maryfuller', 'limit': 10000},
#  846855: {'user': 'maryfuller', 'limit': 10000},
#  66611: {'user': 'allenjennifer', 'limit': 9000},
#  804549: {'user': 'allenjennifer', 'limit': 10000},
#  380955: {'user': 'allenjennifer', 'limit': 10000},
#  235779: {'user': 'allenjennifer', 'limit': 10000},
#  230611: {'user': 'mortonaustin', 'limit': 10000},
#  584594: {'user': 'mortonaustin', 'limit': 10000},
#  987387: {'user': 'cameron30', 'limit': 10000},
#  614135: {'user': 'cameron30', 'limit': 10000},
#  656564: {'user': 'cameron30', 'limit': 10000},
#  962115: {'user': 'willie94', 'limit': 10000},
#  51822: {'user': 'willie94', 'limit': 10000},
#  788442: {'user': 'stewartmichele', 'limit': 10000},
#  644552: {'user': 'stewartmichele', 'limit': 10000},
#  944119: {'user': 'stewartmichele', 'limit': 10000},
#  235687: {'user': 'tateashley', 'limit': 10000},
#  319308: {'user': 'tateashley', 'limit': 10000},
#  452778: {'user': 'tateashley', 'limit': 10000},
#  377923: {'user': 'markwells', 'limit': 10000},
#  433811: {'user': 'robersonmichael', 'limit': 10000},
#  700387: {'user': 'robersonmichael', 'limit': 10000},
#  464470: {'user': 'robersonmichael', 'limit': 10000},
#  987501: {'user': 'robersonmichael', 'limit': 10000},
#  166084: {'user': 'dawsonmelissa', 'limit': 10000},
#  558555: {'user': 'dawsonmelissa', 'limit': 10000},
#  794675: {'user': 'davisjames', 'limit': 10000},
#  463278: {'user': 'davisjames', 'limit': 10000},
#  802829: {'user': 'davisjames', 'limit': 10000},
#  304450: {'user': 'wmanning', 'limit': 10000},
#  892478: {'user': 'wmanning', 'limit': 10000},
#  465052: {'user': 'wmanning', 'limit': 10000},
#  999137: {'user': 'wmanning', 'limit': 10000},
#  719866: {'user': 'janetking', 'limit': 10000},
#  921942: {'user': 'janetking', 'limit': 10000},
#  938326: {'user': 'janetking', 'limit': 10000},
#  177814: {'user': 'janetking', 'limit': 10000},
#  842047: {'user': 'janetking', 'limit': 10000},
#  929644: {'user': 'edwardszachary', 'limit': 10000},
#  937618: {'user': 'edwardszachary', 'limit': 10000},
#  881424: {'user': 'edwardszachary', 'limit': 10000},
#  151378: {'user': 'sarahhayden', 'limit': 10000},
#  132017: {'user': 'sarahhayden', 'limit': 10000},
#  66589: {'user': 'sarahhayden', 'limit': 10000},
#  354107: {'user': 'xrodriguez', 'limit': 7000},
#  165436: {'user': 'xestrada', 'limit': 10000},
#  945366: {'user': 'xestrada', 'limit': 10000},
#  61329: {'user': 'yubarry', 'limit': 10000},
#  87437: {'user': 'yubarry', 'limit': 10000},
#  972041: {'user': 'yubarry', 'limit': 10000},
#  632303: {'user': 'yubarry', 'limit': 10000},
#  194523: {'user': 'hughesann', 'limit': 9000},
#  214555: {'user': 'angelathomas', 'limit': 10000},
#  201862: {'user': 'angelathomas', 'limit': 10000},
#  720825: {'user': 'angelathomas', 'limit': 10000},
#  501408: {'user': 'tknight', 'limit': 10000},
#  618333: {'user': 'caitlinmcdonald', 'limit': 10000},
#  509290: {'user': 'caitlinmcdonald', 'limit': 10000},
#  935023: {'user': 'caitlinmcdonald', 'limit': 10000},
#  207806: {'user': 'caitlinmcdonald', 'limit': 10000},
#  430152: {'user': 'caitlinmcdonald', 'limit': 10000},
#  419542: {'user': 'linda48', 'limit': 10000},
#  356073: {'user': 'linda48', 'limit': 10000},
#  351069: {'user': 'linda48', 'limit': 10000},
#  88799: {'user': 'linda48', 'limit': 10000},
#  861121: {'user': 'linda48', 'limit': 10000},
#  523931: {'user': 'craiglee', 'limit': 10000},
#  990274: {'user': 'hurstmatthew', 'limit': 10000},
#  300879: {'user': 'hurstmatthew', 'limit': 10000},
#  280906: {'user': 'hurstmatthew', 'limit': 10000},
#  692927: {'user': 'hurstmatthew', 'limit': 10000},
#  204117: {'user': 'hurstmatthew', 'limit': 10000},
#  109478: {'user': 'jason27', 'limit': 10000},
#  454704: {'user': 'jose42', 'limit': 10000},
#  884552: {'user': 'jose42', 'limit': 10000},
#  837092: {'user': 'nathaniel64', 'limit': 10000},
#  626698: {'user': 'nathaniel64', 'limit': 10000},
#  401048: {'user': 'nathaniel64', 'limit': 10000},
#  54685: {'user': 'nathaniel64', 'limit': 10000},
#  360655: {'user': 'nathaniel64', 'limit': 10000},
#  912196: {'user': 'jsaunders', 'limit': 10000},
#  610738: {'user': 'jsaunders', 'limit': 10000},
#  549655: {'user': 'jsaunders', 'limit': 10000},
#  326795: {'user': 'peterwolfe', 'limit': 10000},
#  807144: {'user': 'peterwolfe', 'limit': 10000},
#  995007: {'user': 'peterwolfe', 'limit': 10000},
#  507622: {'user': 'peterwolfe', 'limit': 10000},
#  778358: {'user': 'peterwolfe', 'limit': 10000},
#  910579: {'user': 'peterwolfe', 'limit': 10000},
#  905507: {'user': 'stricklandmichael', 'limit': 10000},
#  137090: {'user': 'stricklandmichael', 'limit': 10000},
#  868414: {'user': 'stricklandmichael', 'limit': 10000},
#  529190: {'user': 'stricklandmichael', 'limit': 10000},
#  668348: {'user': 'marysmith', 'limit': 10000},
#  552174: {'user': 'marysmith', 'limit': 10000},
#  917475: {'user': 'marysmith', 'limit': 10000},
#  147334: {'user': 'marysmith', 'limit': 10000},
#  946196: {'user': 'marysmith', 'limit': 10000},
#  254176: {'user': 'marysmith', 'limit': 10000},
#  261962: {'user': 'barnessarah', 'limit': 10000},
#  310074: {'user': 'barnessarah', 'limit': 10000},
#  814632: {'user': 'barnessarah', 'limit': 10000},
#  674132: {'user': 'barnessarah', 'limit': 10000},
#  423254: {'user': 'susanfranco', 'limit': 10000},
#  838304: {'user': 'susanfranco', 'limit': 10000},
#  475102: {'user': 'susanfranco', 'limit': 10000},
#  981028: {'user': 'susanfranco', 'limit': 10000},
#  982027: {'user': 'susanfranco', 'limit': 10000},
#  348352: {'user': 'susanfranco', 'limit': 10000},
#  155156: {'user': 'dana88', 'limit': 10000},
#  529972: {'user': 'dana88', 'limit': 10000},
#  949471: {'user': 'dana88', 'limit': 10000},
#  265862: {'user': 'dana88', 'limit': 10000},
#  911518: {'user': 'jdawson', 'limit': 8000},
#  368168: {'user': 'jdawson', 'limit': 10000},
#  86373: {'user': 'jdawson', 'limit': 10000},
#  141597: {'user': 'jdawson', 'limit': 10000},
#  691022: {'user': 'jdawson', 'limit': 10000},
#  982709: {'user': 'thomascunningham', 'limit': 9000},
#  277161: {'user': 'thomascunningham', 'limit': 10000},
#  498050: {'user': 'thomascunningham', 'limit': 10000},
#  103536: {'user': 'cody34', 'limit': 10000},
#  971879: {'user': 'cody34', 'limit': 10000},
#  609817: {'user': 'katherinenunez', 'limit': 10000},
#  591359: {'user': 'katherinenunez', 'limit': 10000},
#  979257: {'user': 'leechristine', 'limit': 10000},
#  716353: {'user': 'leechristine', 'limit': 10000},
#  623185: {'user': 'leechristine', 'limit': 10000},
#  582902: {'user': 'leechristine', 'limit': 10000},
#  795040: {'user': 'steven28', 'limit': 10000},
#  947606: {'user': 'nicole28', 'limit': 10000},
#  884611: {'user': 'nicole28', 'limit': 10000},
#  210513: {'user': 'nicole28', 'limit': 10000},
#  161597: {'user': 'nicole28', 'limit': 10000},
#  429495: {'user': 'raymond33', 'limit': 10000},
#  541950: {'user': 'raymond33', 'limit': 10000},
#  388334: {'user': 'raymond33', 'limit': 10000},
#  761257: {'user': 'raymond33', 'limit': 10000},
#  586861: {'user': 'nunezdale', 'limit': 10000},
#  633220: {'user': 'nunezdale', 'limit': 10000},
#  639241: {'user': 'nunezdale', 'limit': 10000},
#  201771: {'user': 'nunezdale', 'limit': 10000},
#  467666: {'user': 'crodriguez', 'limit': 10000},
#  470650: {'user': 'lejoshua', 'limit': 10000},
#  443178: {'user': 'lejoshua', 'limit': 10000},
#  491860: {'user': 'wendy61', 'limit': 10000},
#  463155: {'user': 'wendy61', 'limit': 10000},
#  278866: {'user': 'thomas48', 'limit': 10000},
#  78388: {'user': 'thomas48', 'limit': 10000},
#  330961: {'user': 'thomas48', 'limit': 10000},
#  612356: {'user': 'thomas48', 'limit': 10000},
#  126668: {'user': 'thomas48', 'limit': 10000},
#  701440: {'user': 'thomas48', 'limit': 10000},
#  842570: {'user': 'kingraymond', 'limit': 10000},
#  987988: {'user': 'kingraymond', 'limit': 10000},
#  839727: {'user': 'kingraymond', 'limit': 10000},
#  161460: {'user': 'eroberts', 'limit': 10000},
#  740604: {'user': 'eroberts', 'limit': 10000},
#  347313: {'user': 'eroberts', 'limit': 10000},
#  795909: {'user': 'eroberts', 'limit': 10000},
#  689102: {'user': 'eroberts', 'limit': 10000},
#  199962: {'user': 'amanda78', 'limit': 10000},
#  673123: {'user': 'ambercraig', 'limit': 10000},
#  312052: {'user': 'ambercraig', 'limit': 10000},
#  292314: {'user': 'djames', 'limit': 10000},
#  202669: {'user': 'djames', 'limit': 10000},
#  604732: {'user': 'christine68', 'limit': 10000},
#  914559: {'user': 'christine68', 'limit': 10000},
#  346408: {'user': 'christine68', 'limit': 10000},
#  294632: {'user': 'sthompson', 'limit': 10000},
#  782383: {'user': 'sthompson', 'limit': 10000},
#  136139: {'user': 'sthompson', 'limit': 10000},
#  937558: {'user': 'fletchernicole', 'limit': 10000},
#  141237: {'user': 'fletchernicole', 'limit': 10000},
#  891045: {'user': 'kimberlycarpenter', 'limit': 10000},
#  842086: {'user': 'kimberlycarpenter', 'limit': 10000},
#  674464: {'user': 'kimberlycarpenter', 'limit': 10000},
#  341068: {'user': 'pjordan', 'limit': 9000},
#  516709: {'user': 'pjordan', 'limit': 10000},
#  855057: {'user': 'pjordan', 'limit': 10000},
#  744023: {'user': 'pjordan', 'limit': 10000},
#  811931: {'user': 'pjordan', 'limit': 10000},
#  534637: {'user': 'jenniferhopkins', 'limit': 10000},
#  495834: {'user': 'jenniferhopkins', 'limit': 10000},
#  906796: {'user': 'jenniferhopkins', 'limit': 10000},
#  292528: {'user': 'jenniferhopkins', 'limit': 10000},
#  418570: {'user': 'kevinbenson', 'limit': 10000},
#  895006: {'user': 'kevinbenson', 'limit': 10000},
#  236337: {'user': 'davidestrada', 'limit': 10000},
#  533756: {'user': 'davidestrada', 'limit': 10000},
#  246018: {'user': 'nataliebrooks', 'limit': 10000},
#  591354: {'user': 'nataliebrooks', 'limit': 10000},
#  182094: {'user': 'nataliebrooks', 'limit': 10000},
#  565145: {'user': 'nataliebrooks', 'limit': 10000},
#  895434: {'user': 'nataliebrooks', 'limit': 10000},
#  770262: {'user': 'charlotte30', 'limit': 10000},
#  759997: {'user': 'charlotte30', 'limit': 10000},
#  423202: {'user': 'patrick05', 'limit': 10000},
#  180580: {'user': 'patrick05', 'limit': 10000},
#  477706: {'user': 'patrick05', 'limit': 10000},
#  267252: {'user': 'patrick05', 'limit': 10000},
#  749493: {'user': 'patrick05', 'limit': 10000},
#  944895: {'user': 'patrick05', 'limit': 10000},
#  549112: {'user': 'charlescollins', 'limit': 10000},
#  795756: {'user': 'derek98', 'limit': 10000},
#  903651: {'user': 'derek98', 'limit': 10000},
#  149247: {'user': 'derek98', 'limit': 10000},
#  133163: {'user': 'derek98', 'limit': 10000},
#  652071: {'user': 'derek98', 'limit': 10000},
#  921410: {'user': 'derek98', 'limit': 10000},
#  647189: {'user': 'zachary93', 'limit': 10000},
#  443252: {'user': 'zachary93', 'limit': 10000},
#  451189: {'user': 'zachary93', 'limit': 10000},
#  622916: {'user': 'qwaller', 'limit': 9000},
#  53124: {'user': 'qwaller', 'limit': 10000},
#  657243: {'user': 'qwaller', 'limit': 10000},
#  499604: {'user': 'qwaller', 'limit': 10000},
#  168924: {'user': 'qwaller', 'limit': 10000},
#  731206: {'user': 'qwaller', 'limit': 10000},
#  82008: {'user': 'elizabethjackson', 'limit': 10000},
#  855373: {'user': 'elizabethjackson', 'limit': 10000},
#  155475: {'user': 'elizabethjackson', 'limit': 10000},
#  262642: {'user': 'elizabethjackson', 'limit': 10000},
#  105134: {'user': 'elizabethjackson', 'limit': 10000},
#  924182: {'user': 'madeline96', 'limit': 10000},
#  700899: {'user': 'madeline96', 'limit': 10000},
#  226865: {'user': 'madeline96', 'limit': 10000},
#  604215: {'user': 'madeline96', 'limit': 10000},
#  300405: {'user': 'madeline96', 'limit': 10000},
#  980056: {'user': 'madeline96', 'limit': 10000},
#  101920: {'user': 'samantha27', 'limit': 10000},
#  156715: {'user': 'samantha27', 'limit': 10000},
#  515170: {'user': 'samantha27', 'limit': 10000},
#  101383: {'user': 'samantha27', 'limit': 10000},
#  261796: {'user': 'samantha27', 'limit': 10000},
#  803669: {'user': 'samantha27', 'limit': 10000},
#  683108: {'user': 'kylewilliams', 'limit': 10000},
#  138634: {'user': 'kylewilliams', 'limit': 10000},
#  377488: {'user': 'kylewilliams', 'limit': 10000},
#  918519: {'user': 'kylewilliams', 'limit': 10000},
#  637895: {'user': 'kylewilliams', 'limit': 10000},
#  351905: {'user': 'kylewilliams', 'limit': 10000},
#  181212: {'user': 'bakerandre', 'limit': 9000},
#  410092: {'user': 'ecollins', 'limit': 10000},
#  923190: {'user': 'selenamunoz', 'limit': 10000},
#  727418: {'user': 'selenamunoz', 'limit': 10000},
#  59715: {'user': 'nlawson', 'limit': 10000},
#  177799: {'user': 'twright', 'limit': 10000},
#  176639: {'user': 'twright', 'limit': 10000},
#  808642: {'user': 'twright', 'limit': 10000},
#  317556: {'user': 'twright', 'limit': 10000},
#  337202: {'user': 'alexandra72', 'limit': 10000},
#  244662: {'user': 'alexandra72', 'limit': 10000},
#  120472: {'user': 'alexandra72', 'limit': 10000},
#  525945: {'user': 'beverly20', 'limit': 10000},
#  777752: {'user': 'nicolesmith', 'limit': 7000},
#  678779: {'user': 'nicolesmith', 'limit': 10000},
#  87191: {'user': 'perezsarah', 'limit': 10000},
#  642929: {'user': 'perezsarah', 'limit': 10000},
#  738278: {'user': 'perezsarah', 'limit': 10000},
#  74632: {'user': 'perezsarah', 'limit': 10000},
#  77032: {'user': 'perezsarah', 'limit': 10000},
#  544701: {'user': 'whitejill', 'limit': 10000},
#  782938: {'user': 'whitejill', 'limit': 10000},
#  63141: {'user': 'whitejill', 'limit': 10000},
#  712356: {'user': 'whitejill', 'limit': 10000},
#  604077: {'user': 'whitejill', 'limit': 10000},
#  198307: {'user': 'whitejill', 'limit': 10000},
#  514695: {'user': 'peter77', 'limit': 10000},
#  587785: {'user': 'peter77', 'limit': 10000},
#  572301: {'user': 'peter77', 'limit': 10000},
#  198855: {'user': 'peter77', 'limit': 10000},
#  505260: {'user': 'peter77', 'limit': 10000},
#  55104: {'user': 'ncardenas', 'limit': 10000},
#  745028: {'user': 'ncardenas', 'limit': 10000},
#  677943: {'user': 'ncardenas', 'limit': 10000},
#  558048: {'user': 'ncardenas', 'limit': 10000},
#  622628: {'user': 'ncardenas', 'limit': 10000},
#  838666: {'user': 'bryanjones', 'limit': 10000},
#  741535: {'user': 'bryanjones', 'limit': 10000},
#  958411: {'user': 'bryanjones', 'limit': 10000},
#  868418: {'user': 'bryanjones', 'limit': 10000},
#  89646: {'user': 'avaughan', 'limit': 10000},
#  610763: {'user': 'avaughan', 'limit': 10000},
#  925342: {'user': 'avaughan', 'limit': 10000},
#  570599: {'user': 'avaughan', 'limit': 10000},
#  355301: {'user': 'avaughan', 'limit': 10000},
#  624318: {'user': 'zimmermanchristopher', 'limit': 10000},
#  874631: {'user': 'zimmermanchristopher', 'limit': 10000},
#  96224: {'user': 'zimmermanchristopher', 'limit': 10000},
#  129343: {'user': 'hpatrick', 'limit': 10000},
#  744624: {'user': 'hpatrick', 'limit': 10000},
#  303388: {'user': 'hpatrick', 'limit': 10000},
#  711252: {'user': 'hpatrick', 'limit': 10000},
#  928506: {'user': 'hpatrick', 'limit': 10000},
#  265264: {'user': 'hpatrick', 'limit': 10000},
#  841135: {'user': 'avega', 'limit': 10000},
#  57322: {'user': 'avega', 'limit': 10000},
#  177869: {'user': 'briannamercado', 'limit': 10000},
#  253017: {'user': 'briannamercado', 'limit': 10000},
#  357823: {'user': 'yjohnson', 'limit': 10000},
#  175615: {'user': 'yjohnson', 'limit': 10000},
#  122436: {'user': 'yjohnson', 'limit': 10000},
#  460439: {'user': 'holmesjasmine', 'limit': 10000},
#  851625: {'user': 'qnelson', 'limit': 10000},
#  738145: {'user': 'qnelson', 'limit': 10000},
#  591110: {'user': 'qnelson', 'limit': 10000},
#  114739: {'user': 'qnelson', 'limit': 10000},
#  941541: {'user': 'qnelson', 'limit': 10000},
#  572998: {'user': 'qnelson', 'limit': 10000},
#  972116: {'user': 'timothyvelasquez', 'limit': 10000},
#  755845: {'user': 'timothyvelasquez', 'limit': 10000},
#  510435: {'user': 'timothyvelasquez', 'limit': 10000},
#  206973: {'user': 'timothyvelasquez', 'limit': 10000},
#  691917: {'user': 'jeffaustin', 'limit': 10000},
#  249078: {'user': 'tammygonzalez', 'limit': 10000},
#  660047: {'user': 'tammygonzalez', 'limit': 10000},
#  627788: {'user': 'zcole', 'limit': 10000},
#  428217: {'user': 'tammygonzalez', 'limit': 10000},
#  526519: {'user': 'tammygonzalez', 'limit': 10000},
#  814901: {'user': 'tammygonzalez', 'limit': 10000},
#  576646: {'user': 'lisaroberts', 'limit': 10000},
#  168349: {'user': 'wellsjoseph', 'limit': 10000},
#  368133: {'user': 'wellsjoseph', 'limit': 10000},
#  483220: {'user': 'wellsjoseph', 'limit': 10000},
#  558623: {'user': 'karenfarrell', 'limit': 10000},
#  262488: {'user': 'karenfarrell', 'limit': 10000},
#  371349: {'user': 'mwells', 'limit': 10000},
#  849780: {'user': 'mwells', 'limit': 10000},
#  667881: {'user': 'mwells', 'limit': 10000},
#  918539: {'user': 'mwells', 'limit': 10000},
#  147085: {'user': 'mwells', 'limit': 10000},
#  532811: {'user': 'dpitts', 'limit': 10000},
#  701602: {'user': 'dpitts', 'limit': 10000},
#  385025: {'user': 'christophercooper', 'limit': 10000},
#  412109: {'user': 'christophercooper', 'limit': 10000},
#  201161: {'user': 'christophercooper', 'limit': 10000},
#  745392: {'user': 'campbellalicia', 'limit': 10000},
#  385319: {'user': 'campbellalicia', 'limit': 10000},
#  664029: {'user': 'anntaylor', 'limit': 10000},
#  870028: {'user': 'anntaylor', 'limit': 10000},
#  478510: {'user': 'rebecca18', 'limit': 10000},
#  212579: {'user': 'rebecca18', 'limit': 10000},
#  688901: {'user': 'rebecca18', 'limit': 10000},
#  97500: {'user': 'rebecca18', 'limit': 10000},
#  506677: {'user': 'rebecca18', 'limit': 10000},
#  261128: {'user': 'rebecca18', 'limit': 10000},
#  693557: {'user': 'zcole', 'limit': 10000},
#  73934: {'user': 'zcole', 'limit': 10000},
#  539248: {'user': 'zcole', 'limit': 10000},
#  390126: {'user': 'zcole', 'limit': 10000},
#  533671: {'user': 'zcole', 'limit': 10000},
#  384335: {'user': 'lisapowell', 'limit': 10000},
#  317449: {'user': 'lisapowell', 'limit': 10000},
#  719393: {'user': 'lisapowell', 'limit': 10000},
#  556338: {'user': 'lisapowell', 'limit': 10000},
#  671031: {'user': 'kayla67', 'limit': 10000},
#  255267: {'user': 'kayla67', 'limit': 10000},
#  884822: {'user': 'lschwartz', 'limit': 10000},
#  238662: {'user': 'lschwartz', 'limit': 10000},
#  238373: {'user': 'lschwartz', 'limit': 10000},
#  308215: {'user': 'lschwartz', 'limit': 10000},
#  462528: {'user': 'hornlucas', 'limit': 10000},
#  614544: {'user': 'hornlucas', 'limit': 10000},
#  903675: {'user': 'hornlucas', 'limit': 10000},
#  58303: {'user': 'hornlucas', 'limit': 10000},
#  500991: {'user': 'hornlucas', 'limit': 10000},
#  328915: {'user': 'nmason', 'limit': 10000},
#  736326: {'user': 'nmason', 'limit': 10000},
#  655073: {'user': 'nmason', 'limit': 10000},
#  553343: {'user': 'nmason', 'limit': 10000},
#  71148: {'user': 'nmason', 'limit': 10000},
#  484387: {'user': 'nmason', 'limit': 10000},
#  302149: {'user': 'gwendolynwilliams', 'limit': 10000},
#  96431: {'user': 'gwendolynwilliams', 'limit': 10000},
#  987355: {'user': 'gwendolynwilliams', 'limit': 10000},
#  188363: {'user': 'nguyenjulie', 'limit': 10000},
#  183253: {'user': 'nguyenjulie', 'limit': 10000},
#  429119: {'user': 'nguyenjulie', 'limit': 10000},
#  823908: {'user': 'nguyenjulie', 'limit': 10000},
#  618708: {'user': 'nguyenjulie', 'limit': 10000},
#  434613: {'user': 'nguyenjulie', 'limit': 10000},
#  856329: {'user': 'catherine45', 'limit': 10000},
#  219169: {'user': 'catherine45', 'limit': 10000},
#  875074: {'user': 'catherine45', 'limit': 10000},
#  179020: {'user': 'catherine45', 'limit': 10000},
#  753126: {'user': 'catherine45', 'limit': 10000},
#  540237: {'user': 'catherine45', 'limit': 10000},
#  178000: {'user': 'andrea41', 'limit': 10000},
#  885960: {'user': 'andrea41', 'limit': 10000},
#  118134: {'user': 'andrea41', 'limit': 10000},
#  558061: {'user': 'andrea41', 'limit': 10000},
#  216662: {'user': 'andrea41', 'limit': 10000},
#  683393: {'user': 'joneskevin', 'limit': 10000},
#  981710: {'user': 'odonnellbrandon', 'limit': 10000},
#  550456: {'user': 'odonnellbrandon', 'limit': 10000},
#  94177: {'user': 'odonnellbrandon', 'limit': 10000},
#  90414: {'user': 'odonnellbrandon', 'limit': 10000},
#  122551: {'user': 'odonnellbrandon', 'limit': 10000},
#  69394: {'user': 'odonnellbrandon', 'limit': 10000},
#  227194: {'user': 'uortiz', 'limit': 10000},
#  611998: {'user': 'uortiz', 'limit': 10000},
#  730824: {'user': 'uortiz', 'limit': 10000},
#  258443: {'user': 'uortiz', 'limit': 10000},
#  412013: {'user': 'uortiz', 'limit': 10000},
#  434948: {'user': 'uortiz', 'limit': 10000},
#  862214: {'user': 'zcampbell', 'limit': 10000},
#  981035: {'user': 'zcampbell', 'limit': 10000},
#  97487: {'user': 'zcampbell', 'limit': 10000},
#  506845: {'user': 'zcampbell', 'limit': 10000},
#  447044: {'user': 'zcampbell', 'limit': 10000},
#  260504: {'user': 'qjohnson', 'limit': 10000},
#  392268: {'user': 'ashley98', 'limit': 10000},
#  68034: {'user': 'ashley98', 'limit': 10000},
#  287076: {'user': 'courtneyholland', 'limit': 10000},
#  782023: {'user': 'courtneyholland', 'limit': 10000},
#  568897: {'user': 'courtneyholland', 'limit': 10000},
#  905866: {'user': 'courtneyholland', 'limit': 10000},
#  444626: {'user': 'scottfisher', 'limit': 10000},
#  570536: {'user': 'scottfisher', 'limit': 10000},
#  761387: {'user': 'scottfisher', 'limit': 10000},
#  879203: {'user': 'steve73', 'limit': 10000},
#  932908: {'user': 'steve73', 'limit': 10000},
#  712597: {'user': 'steve73', 'limit': 10000},
#  798380: {'user': 'steve73', 'limit': 10000},
#  802298: {'user': 'steve73', 'limit': 10000},
#  413410: {'user': 'courtneysexton', 'limit': 10000},
#  585228: {'user': 'pwarren', 'limit': 10000},
#  225511: {'user': 'pwarren', 'limit': 10000},
#  371974: {'user': 'pwarren', 'limit': 10000},
#  234369: {'user': 'jeremiah94', 'limit': 9000},
#  437245: {'user': 'jeremiah94', 'limit': 10000},
#  333684: {'user': 'jeremiah94', 'limit': 10000},
#  120917: {'user': 'jeremiah94', 'limit': 10000},
#  248398: {'user': 'jeremiah94', 'limit': 10000},
#  909802: {'user': 'jeremiah94', 'limit': 10000},
#  445672: {'user': 'cbradley', 'limit': 10000},
#  603062: {'user': 'mirandajones', 'limit': 10000},
#  807359: {'user': 'mirandajones', 'limit': 10000},
#  827390: {'user': 'mirandajones', 'limit': 10000},
#  918097: {'user': 'mirandajones', 'limit': 10000},
#  835570: {'user': 'mirandajones', 'limit': 10000},
#  489563: {'user': 'mirandajones', 'limit': 10000},
#  661661: {'user': 'pbrown', 'limit': 10000},
#  314671: {'user': 'pbrown', 'limit': 10000},
#  371629: {'user': 'pbrown', 'limit': 10000},
#  718678: {'user': 'pbrown', 'limit': 10000},
#  816225: {'user': 'robin78', 'limit': 10000},
#  501213: {'user': 'robin78', 'limit': 10000},
#  960469: {'user': 'robin78', 'limit': 10000},
#  950785: {'user': 'robin78', 'limit': 10000},
#  344107: {'user': 'robin78', 'limit': 10000},
#  953567: {'user': 'obrienstephanie', 'limit': 10000},
#  147275: {'user': 'obrienstephanie', 'limit': 10000},
#  546681: {'user': 'obrienstephanie', 'limit': 10000},
#  463119: {'user': 'eric29', 'limit': 10000},
#  89466: {'user': 'eric29', 'limit': 10000},
#  141586: {'user': 'eric29', 'limit': 10000},
#  765101: {'user': 'eric29', 'limit': 10000},
#  208252: {'user': 'utorres', 'limit': 10000},
#  936999: {'user': 'utorres', 'limit': 10000},
#  825051: {'user': 'utorres', 'limit': 10000},
#  943710: {'user': 'utorres', 'limit': 10000},
#  292224: {'user': 'utorres', 'limit': 10000},
#  307731: {'user': 'utorres', 'limit': 10000},
#  59378: {'user': 'patrick05', 'limit': 10000},
#  181687: {'user': 'patrick05', 'limit': 10000},
#  448304: {'user': 'patrick05', 'limit': 10000},
#  754737: {'user': 'patrick05', 'limit': 10000},
#  176390: {'user': 'patrick05', 'limit': 10000},
#  304194: {'user': 'hardinsharon', 'limit': 10000},
#  635729: {'user': 'jennifer54', 'limit': 10000},
#  784910: {'user': 'jennifer54', 'limit': 10000},
#  600800: {'user': 'jennifer54', 'limit': 10000},
#  741762: {'user': 'jennifer54', 'limit': 10000},
#  95914: {'user': 'stephenthompson', 'limit': 10000},
#  675420: {'user': 'stephenthompson', 'limit': 10000},
#  657121: {'user': 'stephenthompson', 'limit': 10000},
#  195007: {'user': 'stephenthompson', 'limit': 10000},
#  181984: {'user': 'joshua27', 'limit': 10000},
#  175926: {'user': 'joshua27', 'limit': 10000},
#  708479: {'user': 'joshua27', 'limit': 10000},
#  690308: {'user': 'joshua27', 'limit': 10000},
#  770312: {'user': 'joshua25', 'limit': 10000},
#  333075: {'user': 'joshua25', 'limit': 10000},
#  396162: {'user': 'joshua25', 'limit': 10000},
#  642554: {'user': 'joshua25', 'limit': 10000},
#  938988: {'user': 'joshua25', 'limit': 10000},
#  992584: {'user': 'marc02', 'limit': 10000},
#  475604: {'user': 'marc02', 'limit': 10000},
#  720906: {'user': 'marc02', 'limit': 10000},
#  328466: {'user': 'marc02', 'limit': 10000},
#  692070: {'user': 'marc02', 'limit': 10000},
#  445713: {'user': 'patriciawade', 'limit': 10000},
#  588012: {'user': 'patriciawade', 'limit': 10000},
#  351206: {'user': 'patriciawade', 'limit': 10000},
#  105098: {'user': 'patriciawade', 'limit': 10000},
#  402535: {'user': 'maxwellhannah', 'limit': 10000},
#  833855: {'user': 'maxwellhannah', 'limit': 10000},
#  994562: {'user': 'maxwellhannah', 'limit': 10000},
#  951224: {'user': 'maxwellhannah', 'limit': 10000},
#  415759: {'user': 'maxwellhannah', 'limit': 10000},
#  700455: {'user': 'mariebrady', 'limit': 10000},
#  828552: {'user': 'mariebrady', 'limit': 10000},
#  876702: {'user': 'mariebrady', 'limit': 10000},
#  525396: {'user': 'mariebrady', 'limit': 10000},
#  846426: {'user': 'uwhite', 'limit': 10000},
#  727837: {'user': 'uwhite', 'limit': 10000},
#  743212: {'user': 'uwhite', 'limit': 10000},
#  667791: {'user': 'uwhite', 'limit': 10000},
#  835955: {'user': 'kroberts', 'limit': 10000},
#  717404: {'user': 'kroberts', 'limit': 10000},
#  55473: {'user': 'kroberts', 'limit': 10000},
#  466489: {'user': 'kroberts', 'limit': 10000},
#  980639: {'user': 'kroberts', 'limit': 10000},
#  999198: {'user': 'odonovan', 'limit': 10000},
#  614528: {'user': 'odonovan', 'limit': 10000},
#  421981: {'user': 'odonovan', 'limit': 10000},
#  545935: {'user': 'odonovan', 'limit': 10000},
#  872805: {'user': 'odonovan', 'limit': 10000},
#  248380: {'user': 'brenda56', 'limit': 10000},
#  244782: {'user': 'brenda56', 'limit': 10000},
#  374953: {'user': 'amanda41', 'limit': 10000},
#  79999: {'user': 'amanda41', 'limit': 10000},
#  852208: {'user': 'amanda41', 'limit': 10000},
#  320075: {'user': 'amanda41', 'limit': 10000},
#  664533: {'user': 'fordjames', 'limit': 10000},
#  700611: {'user': 'fordjames', 'limit': 10000},
#  59275: {'user': 'fordjames', 'limit': 10000},
#  150321: {'user': 'landerson', 'limit': 10000},
#  527745: {'user': 'landerson', 'limit': 10000},
#  992173: {'user': 'landerson', 'limit': 10000},
#  423152: {'user': 'david37', 'limit': 10000},
#  157990: {'user': 'david37', 'limit': 10000},
#  617243: {'user': 'david37', 'limit': 10000},
#  679340: {'user': 'william51', 'limit': 10000},
#  146967: {'user': 'william51', 'limit': 10000},
#  617621: {'user': 'william51', 'limit': 10000},
#  596107: {'user': 'william51', 'limit': 10000},
#  385747: {'user': 'william51', 'limit': 10000},
#  881867: {'user': 'andreaking', 'limit': 10000},
#  329183: {'user': 'andreaking', 'limit': 10000},
#  481744: {'user': 'andreaking', 'limit': 10000},
#  996752: {'user': 'nicholas29', 'limit': 10000},
#  289795: {'user': 'brownanne', 'limit': 10000},
#  384574: {'user': 'brownanne', 'limit': 10000},
#  981753: {'user': 'erikadavis', 'limit': 9000},
#  388950: {'user': 'erikadavis', 'limit': 10000},
#  171129: {'user': 'paultorres', 'limit': 10000},
#  624886: {'user': 'paultorres', 'limit': 10000},
#  784651: {'user': 'paultorres', 'limit': 10000},
#  51253: {'user': 'paultorres', 'limit': 10000},
#  255004: {'user': 'paultorres', 'limit': 10000},
#  657880: {'user': 'paultorres', 'limit': 10000},
#  87286: {'user': 'ogreen', 'limit': 10000},
#  886274: {'user': 'ogreen', 'limit': 10000},
#  569434: {'user': 'ogreen', 'limit': 10000},
#  70492: {'user': 'thompsonkevin', 'limit': 10000},
#  327916: {'user': 'thompsonkevin', 'limit': 10000},
#  109710: {'user': 'thompsonkevin', 'limit': 10000},
#  996624: {'user': 'joseph83', 'limit': 10000},
#  242287: {'user': 'joseph83', 'limit': 10000},
#  704067: {'user': 'toneal', 'limit': 10000},
#  481754: {'user': 'toneal', 'limit': 10000},
#  131371: {'user': 'toneal', 'limit': 10000},
#  291224: {'user': 'toneal', 'limit': 10000},
#  774172: {'user': 'rachel83', 'limit': 10000},
#  765127: {'user': 'amanda70', 'limit': 10000},
#  460206: {'user': 'amanda70', 'limit': 10000},
#  344075: {'user': 'amanda70', 'limit': 10000},
#  313926: {'user': 'amanda70', 'limit': 10000},
#  322023: {'user': 'amanda70', 'limit': 10000},
#  703331: {'user': 'williamstone', 'limit': 10000},
#  598715: {'user': 'jperez', 'limit': 10000},
#  873264: {'user': 'jperez', 'limit': 10000},
#  228298: {'user': 'jperez', 'limit': 10000},
#  549289: {'user': 'jperez', 'limit': 10000},
#  764007: {'user': 'jperez', 'limit': 10000},
#  960568: {'user': 'jperez', 'limit': 10000},
#  581892: {'user': 'ebonyoconnor', 'limit': 10000},
#  428110: {'user': 'ebonyoconnor', 'limit': 10000},
#  891056: {'user': 'ebonyoconnor', 'limit': 10000},
#  466310: {'user': 'ebonyoconnor', 'limit': 10000},
#  356904: {'user': 'rmason', 'limit': 9000},
#  134434: {'user': 'rmason', 'limit': 10000},
#  499796: {'user': 'rmason', 'limit': 10000},
#  698826: {'user': 'rmason', 'limit': 10000},
#  763879: {'user': 'rmason', 'limit': 10000},
#  442170: {'user': 'rmason', 'limit': 10000},
#  681381: {'user': 'hallyvonne', 'limit': 10000},
#  524194: {'user': 'hallyvonne', 'limit': 10000},
#  347967: {'user': 'hallyvonne', 'limit': 10000},
#  389592: {'user': 'hallyvonne', 'limit': 10000},
#  385361: {'user': 'simpsonjared', 'limit': 7000},
#  506711: {'user': 'simpsonjared', 'limit': 10000},
#  719203: {'user': 'simpsonjared', 'limit': 10000},
#  882090: {'user': 'simpsonjared', 'limit': 10000},
#  569420: {'user': 'simpsonjared', 'limit': 10000},
#  546211: {'user': 'simpsonjared', 'limit': 10000},
#  912589: {'user': 'riversmckenzie', 'limit': 10000},
#  788012: {'user': 'riversmckenzie', 'limit': 10000},
#  185549: {'user': 'riversmckenzie', 'limit': 10000},
#  497088: {'user': 'riversmckenzie', 'limit': 10000},
#  602958: {'user': 'riversmckenzie', 'limit': 10000},
#  537158: {'user': 'riversmckenzie', 'limit': 10000},
#  530132: {'user': 'nicholasbarber', 'limit': 10000},
#  744022: {'user': 'nicholasbarber', 'limit': 10000},
#  743205: {'user': 'nicholasbarber', 'limit': 10000},
#  182387: {'user': 'leeryan', 'limit': 10000},
#  618428: {'user': 'leeryan', 'limit': 10000},
#  611752: {'user': 'michael22', 'limit': 10000},
#  678293: {'user': 'michael22', 'limit': 10000},
#  214649: {'user': 'christinadavies', 'limit': 10000},
#  557547: {'user': 'christinadavies', 'limit': 10000},
#  639934: {'user': 'christinadavies', 'limit': 10000},
#  659017: {'user': 'christinadavies', 'limit': 10000},
#  405559: {'user': 'melissaho', 'limit': 9000},
#  564812: {'user': 'melissaho', 'limit': 10000},
#  447601: {'user': 'melissaho', 'limit': 10000},
#  682382: {'user': 'melissaho', 'limit': 10000},
#  446474: {'user': 'melissaho', 'limit': 10000},
#  239538: {'user': 'nathaniel41', 'limit': 10000},
#  218214: {'user': 'nathaniel41', 'limit': 10000},
#  442616: {'user': 'nathaniel41', 'limit': 10000},
#  60664: {'user': 'jeremyclark', 'limit': 9000},
#  265053: {'user': 'michael26', 'limit': 10000},
#  86494: {'user': 'michael26', 'limit': 10000},
#  619619: {'user': 'michael26', 'limit': 10000},
#  428949: {'user': 'michael26', 'limit': 10000},
#  275187: {'user': 'michael26', 'limit': 10000},
#  857689: {'user': 'keithbuck', 'limit': 10000},
#  616016: {'user': 'keithbuck', 'limit': 10000},
#  979226: {'user': 'keithbuck', 'limit': 10000},
#  257801: {'user': 'keithbuck', 'limit': 10000},
#  569388: {'user': 'gonzalesgabriel', 'limit': 10000},
#  816560: {'user': 'gonzalesgabriel', 'limit': 10000},
#  328686: {'user': 'gonzalesgabriel', 'limit': 10000},
#  373169: {'user': 'nathan71', 'limit': 10000},
#  833412: {'user': 'diazsharon', 'limit': 10000},
#  752970: {'user': 'diazsharon', 'limit': 10000},
#  935353: {'user': 'diazsharon', 'limit': 10000},
#  172950: {'user': 'dominique55', 'limit': 10000},
#  576395: {'user': 'dominique55', 'limit': 10000},
#  844838: {'user': 'dominique55', 'limit': 10000},
#  453480: {'user': 'dominique55', 'limit': 10000},
#  240685: {'user': 'dominique55', 'limit': 10000},
#  893678: {'user': 'meganbrewer', 'limit': 10000},
#  232492: {'user': 'meganbrewer', 'limit': 10000},
#  380860: {'user': 'meganbrewer', 'limit': 10000},
#  893845: {'user': 'meganbrewer', 'limit': 10000},
#  643169: {'user': 'meganbrewer', 'limit': 10000},
#  935768: {'user': 'sarathompson', 'limit': 10000},
#  131201: {'user': 'sarathompson', 'limit': 10000},
#  317852: {'user': 'sarathompson', 'limit': 10000},
#  683382: {'user': 'sarathompson', 'limit': 10000},
#  814989: {'user': 'justinjohnson', 'limit': 10000},
#  509009: {'user': 'justinjohnson', 'limit': 10000},
#  913254: {'user': 'justinjohnson', 'limit': 10000},
#  352837: {'user': 'justinjohnson', 'limit': 10000},
#  132536: {'user': 'eugene04', 'limit': 10000},
#  617210: {'user': 'eugene04', 'limit': 10000},
#  222581: {'user': 'kristen26', 'limit': 10000},
#  996840: {'user': 'kristen26', 'limit': 10000},
#  650729: {'user': 'amandawilliams', 'limit': 10000},
#  991663: {'user': 'amandawilliams', 'limit': 10000},
#  144876: {'user': 'amandawilliams', 'limit': 10000},
#  912504: {'user': 'amandawilliams', 'limit': 10000},
#  88163: {'user': 'amandawilliams', 'limit': 10000},
#  568852: {'user': 'qknight', 'limit': 10000},
#  351063: {'user': 'qknight', 'limit': 10000},
#  635650: {'user': 'qknight', 'limit': 10000},
#  229182: {'user': 'qknight', 'limit': 10000},
#  732327: {'user': 'qknight', 'limit': 10000},
#  89698: {'user': 'qknight', 'limit': 10000},
#  896364: {'user': 'ecasey', 'limit': 9000},
#  450464: {'user': 'ecasey', 'limit': 10000}}

# %% [markdown]
# This may look a little intimidating but actually its nothing massively new. We create dictionary to post our joined results to. Secondly we create an empty list in which we will add every account ID associated with a customer older than our cut-off.
#
# The first for loop executes the above - adding anyone older than our date who has a username and at least one account to the dictionary. The key for our disctionary is the account ID (so each customer can be listed multiple times) and the values are a nested dictionary containing the "username" and account "limit" (we set the initial "limit" to be "Unknown" as we need to get this from the other collection). We also keep a list of all the account IDs ("first_query").
#
# After this we loop through the _accounts_ collection but only extract records where the "account_id" is included in the "first_query" list (in other words a LEFT JOIN in SQL terminology). With these filtered results we update the dictionary to change the limit to whatever the limit is in the _accounts_ collection.
#
# We could imagine this as a SQL query as something like the following (note - this is SQL code so won't run in the Notebook):

# %%
'''
SELECT account, username AS user
FROM customers
WHERE birthdate < DATE("1981/06/13")
LEFT JOIN accounts
ON customers.account = accounts.account_ID;
'''
# Out:
# '\nSELECT account, username AS user\nFROM customers\nWHERE birthdate < DATE("1981/06/13")\nLEFT JOIN accounts\nON customers.account = accounts.account_ID;\n'

# %% [markdown]
# _Note however this SQL would not work as we do not have one record per account ID but each record has a list of account IDs. We would typically have designed around this with an account_ID to customer_ID lookup table. However, this does highlight the extra flexibility of NoSQL - that we can have a list within a field within a collection._

# %% [markdown]
# Our final step will be outputing our joined table, using _pandas:_

# %%
import pandas as pd

outputdf = pd.DataFrame(output)
outputdf = outputdf.transpose()
outputdf.reset_index(inplace=True)
outputdf.rename(columns = {"index": "account_id"}, inplace=True)

print(outputdf.head())

outputdf.to_csv("mongoout.csv", index=False)
# Out:
#    account_id     user  limit
# 0      371138  fmiller   9000
# 1      324287  fmiller  10000
# 2      276528  fmiller  10000
# 3      332179  fmiller  10000
# 4      422649  fmiller  10000

# %% [markdown]
# Slightly tougher Notebook - well done if you made it this far!!!
