# %% [markdown]
# # Extracting API Data Part II: This time with _request_ and _json_

# %% [markdown]
# We're going to revist API data by using a different API, and in doing so switching to a more conventional JSON format of response (the _arXiv_ API returns an XML response). In doing so we can extract raw data from our response with greater ease and also working with JSON will have advantages with our database choice for later sessions (and the IMA). Let's start by importing some packages:

# %%
import requests
import pandas as pd 
import json
import time

# %% [markdown]
# We'll use _requests_ rather than _urllib_ as we did in the Web Scraping tutorial. We're also using Python's in-built _json_ library to decode the data we receive.
#
# Next we'll set up an API call:

# %%
location_url = "https://www.metaweather.com/api/location/search/?query="

def location_generator(query="London"):
    query = query.replace(" ", "%20")
    r = requests.get(location_url + query)
    return r

# %% [markdown]
# As you may be able to infer, our API is based on weather data. You can read the API documentation [here](https://www.metaweather.com/api/). Our overall goal is to write some to find the average temperature in several international cities and store them somewhere. The first part of this is finding the ID of the city we want to query.
#
# In terms of the code, we're being a little bit cuter here than we have previously by building a function to make multi-searches a bit easier. We start with a base URL (everything apart from the search query) - "location_url". Secondly we are including in this a solution for when the city has a space in it. (Recall back from the previous Extracting API Data session that spaces needed to be encoded as "%20"). Our _replace()_ code will find any spaces in the text and replace them with "%20". Lastly we also have a default value for the query - "London". If the user doesn't pass a city it will default to London. Let's test this:

# %%
r = location_generator()
r.content
# Out:
# b'[{"title":"London","location_type":"City","woeid":44418,"latt_long":"51.506321,-0.12714"}]'

# %% [markdown]
# Everything seems to have worked! Let's also test our "%20" encoding with a two-word city name:

# %%
r = location_generator("New York")
r.content
# Out:
# b'[{"title":"New York","location_type":"City","woeid":2459115,"latt_long":"40.71455,-74.007118"}]'

# %% [markdown]
# Finally we will settle on the world's favourite city ...

# %%
r = location_generator("Coventry")
r.content
# Out:
# b'[{"title":"Coventry","location_type":"City","woeid":17044,"latt_long":"52.406979,-1.507760"}]'

# %% [markdown]
# The element we need from this is the location ID ("woeid"). _json_ provides an easy solution for convering our data into a dictionary:

# %%
response_list = r.json()
response_list
# Out:
# [{'title': 'Coventry',
#   'location_type': 'City',
#   'woeid': 17044,
#   'latt_long': '52.406979,-1.507760'}]

# %% [markdown]
# So now we should be able to just get the value by using the key ... right?

# %%
response_list["woeid"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_468/1826381783.py in <module>
# ----> 1 response_list["woeid"]
#
# TypeError: list indices must be integers or slices, not str

# %% [markdown]
# Oh dear! Error. Why is this? If we look at the output of [6] we should see our dictionary is actually inside a list ... "[ ]". We can get the data by first requesting the 0th item of the list:

# %%
response_list[0]["woeid"]
# Out:
# 17044

# %% [markdown]
# Success! We can now move on to the second part of the task which is to get the weather on a particular day. Again we will do this with a function as below:

# %%
weather_url = "https://www.metaweather.com/api/location/"

def weather_generator(woeid=44418, day="2022/01/07"):
    r = requests.get(weather_url + str(woeid) + "/" + day)
    return r

# %% [markdown]
# The API call needs a location ID and a date. Again we add defaults to each in our function. We can try to get our Coventry weather using the default date (17th Jan 2022):

# %%
w = weather_generator(woeid=17044)
w.content
# Out:
# b'[{"id":5475309177536512,"weather_state_name":"Light Rain","weather_state_abbr":"lr","wind_direction_compass":"WSW","created":"2022-01-07T23:22:04.486780Z","applicable_date":"2022-01-07","min_temp":0.615,"max_temp":4.779999999999999,"the_temp":4.535,"wind_speed":9.12643789097537,"wind_direction":250.4997332413852,"air_pressure":1009.0,"humidity":78,"visibility":11.757896385110952,"predictability":75},{"id":4666185120481280,"weather_state_name":"Light Rain","weather_state_abbr":"lr","wind_direction_compass":"WSW","created":"2022-01-07T20:22:04.053026Z","applicable_date":"2022-01-07","min_temp":0.32999999999999996,"max_temp":4.64,"the_temp":4.505,"wind_speed":9.13679407751266,"wind_direction":250.4997332413852,"air_pressure":1009.0,"humidity":79,"visibility":11.757896385110952,"predictability":75},{"id":6324366129233920,"weather_state_name":"Light Rain","weather_state_abbr":"lr","wind_direction_compass":"WSW","created":"2022-01-07T17:22:05.848284Z","applicable_date":"2022-01-07","min_temp":0.57,"max_temp":4.67,"the_temp":4.505,"wind_speed":9.18679407751266,"wind_direction":250.4997332413852,"air_pressure":1009.0,"humidity":78,"visibility":11.757896385110952,"predictability":75},{"id":6672329078734848,"weather_state_name":"Showers","weather_state_abbr":"s","wind_direction_compass":"WSW","created":"2022-01-07T14:22:04.870287Z","applicable_date":"2022-01-07","min_temp":0.61,"max_temp":4.58,"the_temp":4.125,"wind_speed":8.913805587648135,"wind_direction":252.82704328967526,"air_pressure":1007.5,"humidity":79,"visibility":13.095708561997931,"predictability":73},{"id":5908560245424128,"weather_state_name":"Showers","weather_state_abbr":"s","wind_direction_compass":"WSW","created":"2022-01-07T11:22:04.552893Z","applicable_date":"2022-01-07","min_temp":0.545,"max_temp":4.51,"the_temp":3.93,"wind_speed":9.914803020981468,"wind_direction":253.1617655408795,"air_pressure":1007.5,"humidity":81,"visibility":15.458161834884276,"predictability":73},{"id":4828343120691200,"weather_state_name":"Light Rain","weather_state_abbr":"lr","wind_direction_compass":"WSW","created":"2022-01-07T08:22:03.842443Z","applicable_date":"2022-01-07","min_temp":0.6,"max_temp":4.65,"the_temp":4.199999999999999,"wind_speed":10.002209193409158,"wind_direction":254.15606628776976,"air_pressure":1008.5,"humidity":80,"visibility":14.524240932951562,"predictability":75},{"id":4559821765345280,"weather_state_name":"Light Rain","weather_state_abbr":"lr","wind_direction_compass":"WSW","created":"2022-01-07T05:22:04.458876Z","applicable_date":"2022-01-07","min_temp":0.6,"max_temp":4.65,"the_temp":4.14,"wind_speed":9.890362693409157,"wind_direction":254.15606628776976,"air_pressure":1008.5,"humidity":78,"visibility":15.352528732203929,"predictability":75},{"id":5349984548421632,"weather_state_name":"Heavy Rain","weather_state_abbr":"hr","wind_direction_compass":"SW","created":"2022-01-07T02:22:04.667169Z","applicable_date":"2022-01-07","min_temp":0.605,"max_temp":4.53,"the_temp":4.255,"wind_speed":7.9844424362310775,"wind_direction":230.71049243610645,"air_pressure":1011.5,"humidity":79,"visibility":5.203673049391553,"predictability":77},{"id":5551581253599232,"weather_state_name":"Showers","weather_state_abbr":"s","wind_direction_compass":"WSW","created":"2022-01-06T23:22:07.342273Z","applicable_date":"2022-01-07","min_temp":0.605,"max_temp":4.53,"the_temp":3.815,"wind_speed":9.818725036231077,"wind_direction":251.49954243800184,"air_pressure":1008.5,"humidity":79,"visibility":14.546299610275987,"predictability":73},{"id":6325946073219072,"weather_state_name":"Light Rain","weather_state_abbr":"lr","wind_direction_compass":"WSW","created":"2022-01-06T20:22:07.082426Z","applicable_date":"2022-01-07","min_temp":0.8,"max_temp":4.390000000000001,"the_temp":4.17,"wind_speed":9.82245330533153,"wind_direction":250.16687359363726,"air_pressure":1008.5,"humidity":80,"visibility":14.813489222938042,"predictability":75},{"id":5539180718325760,"weather_state_name":"Light Rain","weather_ ...

# %% [markdown]
# A very long and hard to read list. Let's see if _json_ can help:

# %%
weather_list = w.json()
weather_list
# Out:
# [{'id': 5475309177536512,
#   'weather_state_name': 'Light Rain',
#   'weather_state_abbr': 'lr',
#   'wind_direction_compass': 'WSW',
#   'created': '2022-01-07T23:22:04.486780Z',
#   'applicable_date': '2022-01-07',
#   'min_temp': 0.615,
#   'max_temp': 4.779999999999999,
#   'the_temp': 4.535,
#   'wind_speed': 9.12643789097537,
#   'wind_direction': 250.4997332413852,
#   'air_pressure': 1009.0,
#   'humidity': 78,
#   'visibility': 11.757896385110952,
#   'predictability': 75},
#  {'id': 4666185120481280,
#   'weather_state_name': 'Light Rain',
#   'weather_state_abbr': 'lr',
#   'wind_direction_compass': 'WSW',
#   'created': '2022-01-07T20:22:04.053026Z',
#   'applicable_date': '2022-01-07',
#   'min_temp': 0.32999999999999996,
#   'max_temp': 4.64,
#   'the_temp': 4.505,
#   'wind_speed': 9.13679407751266,
#   'wind_direction': 250.4997332413852,
#   'air_pressure': 1009.0,
#   'humidity': 79,
#   'visibility': 11.757896385110952,
#   'predictability': 75},
#  {'id': 6324366129233920,
#   'weather_state_name': 'Light Rain',
#   'weather_state_abbr': 'lr',
#   'wind_direction_compass': 'WSW',
#   'created': '2022-01-07T17:22:05.848284Z',
#   'applicable_date': '2022-01-07',
#   'min_temp': 0.57,
#   'max_temp': 4.67,
#   'the_temp': 4.505,
#   'wind_speed': 9.18679407751266,
#   'wind_direction': 250.4997332413852,
#   'air_pressure': 1009.0,
#   'humidity': 78,
#   'visibility': 11.757896385110952,
#   'predictability': 75},
#  {'id': 6672329078734848,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'WSW',
#   'created': '2022-01-07T14:22:04.870287Z',
#   'applicable_date': '2022-01-07',
#   'min_temp': 0.61,
#   'max_temp': 4.58,
#   'the_temp': 4.125,
#   'wind_speed': 8.913805587648135,
#   'wind_direction': 252.82704328967526,
#   'air_pressure': 1007.5,
#   'humidity': 79,
#   'visibility': 13.095708561997931,
#   'predictability': 73},
#  {'id': 5908560245424128,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'WSW',
#   'created': '2022-01-07T11:22:04.552893Z',
#   'applicable_date': '2022-01-07',
#   'min_temp': 0.545,
#   'max_temp': 4.51,
#   'the_temp': 3.93,
#   'wind_speed': 9.914803020981468,
#   'wind_direction': 253.1617655408795,
#   'air_pressure': 1007.5,
#   'humidity': 81,
#   'visibility': 15.458161834884276,
#   'predictability': 73},
#  {'id': 4828343120691200,
#   'weather_state_name': 'Light Rain',
#   'weather_state_abbr': 'lr',
#   'wind_direction_compass': 'WSW',
#   'created': '2022-01-07T08:22:03.842443Z',
#   'applicable_date': '2022-01-07',
#   'min_temp': 0.6,
#   'max_temp': 4.65,
#   'the_temp': 4.199999999999999,
#   'wind_speed': 10.002209193409158,
#   'wind_direction': 254.15606628776976,
#   'air_pressure': 1008.5,
#   'humidity': 80,
#   'visibility': 14.524240932951562,
#   'predictability': 75},
#  {'id': 4559821765345280,
#   'weather_state_name': 'Light Rain',
#   'weather_state_abbr': 'lr',
#   'wind_direction_compass': 'WSW',
#   'created': '2022-01-07T05:22:04.458876Z',
#   'applicable_date': '2022-01-07',
#   'min_temp': 0.6,
#   'max_temp': 4.65,
#   'the_temp': 4.14,
#   'wind_speed': 9.890362693409157,
#   'wind_direction': 254.15606628776976,
#   'air_pressure': 1008.5,
#   'humidity': 78,
#   'visibility': 15.352528732203929,
#   'predictability': 75},
#  {'id': 5349984548421632,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'SW',
#   'created': '2022-01-07T02:22:04.667169Z',
#   'applicable_date': '2022-01-07',
#   'min_temp': 0.605,
#   'max_temp': 4.53,
#   'the_temp': 4.255,
#   'wind_speed': 7.9844424362310775,
#   'wind_direction': 230.71049243610645,
#   'air_pressure': 1011.5,
#   'humidity': 79,
#   'visibility': 5.203673049391553,
#   'predictability': 77},
#  {'id': 5551581253599232,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'WSW',
#   'created': '2022-01-06T23:22:07.342273Z',
#   'applicable_date': '2022-01-07',
#   'min_temp': 0.605,
#   'max_temp': 4.53,
#   'the_temp': 3.815,
#   'wind_speed': 9.818725036231077,
#   'wind_direction': 251.49954243800184,
#   'air_pressure': 1008.5,
#   'humidity': 79,
#   'visibility': 14.546299610275987,
#   'predictability': 73},
#  {'id': 6325946073219072,
#   'weather_state_name': 'Light Rain',
#   'weather_state_abbr': 'lr',
#   'wind_direction_compass': 'WSW',
#   'created': '2022-01-06T20:22:07.082426Z',
#   'applicable_date': '2022-01-07',
#   'min_temp': 0.8,
#   'max_temp': 4.390000000000001,
#   'the_temp': 4.17,
#   'wind_speed': 9.82245330533153,
#   'wind_direction': 250.16687359363726,
#   'air_pressure': 1008.5,
#   'humidity': 80,
#   'visibility': 14.813489222938042,
#   'predictability': 75},
#  {'id': 5539180718325760,
#   'weather_state_name': 'Light Rain',
#   'weather_state_abbr': 'lr',
#   'wind_direction_compass': 'WSW',
#   'created': '2022-01-06T17:22:07.356014Z',
#   'applicable_date': '2022-01-07',
#   'min_temp': 0.68,
#   'max_temp': 4.470000000000001,
#   'the_temp': 4.09,
#   'wind_speed': 9.75245330533153,
#   'wind_direction': 249.83337612796305,
#   'air_pressure': 1008.5,
#   'humidity': 79,
#   'visibility': 15.35905312972242,
#   'predictability': 75},
#  {'id': 4856093575479296,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'WSW',
#   'created': '2022-01-06T14:22:07.188989Z',
#   'applicable_date': '2022-01-07',
#   'min_temp': 0.555,
#   'max_temp': 4.115,
#   'the_temp': 3.75,
#   'wind_speed': 9.547815122275246,
#   'wind_direction': 249.16672543706716,
#   'air_pressure': 1009.0,
#   'humidity': 81,
#   'visibility': 15.888772071104748,
#   'predictability': 77},
#  {'id': 5943246703296512,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'WSW',
#   'created': '2022-01-06T11:22:07.442184Z',
#   'applicable_date': '2022-01-07',
#   'min_temp': 0.42000000000000004,
#   'max_temp': 3.99,
#   'the_temp': 3.755,
#   'wind_speed': 9.242112488941913,
#   'wind_direction': 248.16659425877583,
#   'air_pressure': 1009.0,
#   'humidity': 81,
#   'visibility': 14.492861687743577,
#   'predictability': 77},
#  {'id': 6166208253526016,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'WSW',
#   'created': '2022-01-06T08:22:06.760794Z',
#   'applicable_date': '2022-01-07',
#   'min_temp': 0.54,
#   'max_temp': 3.93,
#   'the_temp': 3.835,
#   'wind_speed': 9.210215937771414,
#   'wind_direction': 249.49885635660405,
#   'air_pressure': 1008.5,
#   'humidity': 80,
#   'visibility': 14.573329257138312,
#   'predictability': 77},
#  {'id': 6332866003730432,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'WSW',
#   'created': '2022-01-06T05:22:06.764722Z',
#   'applicable_date': '2022-01-07',
#   'min_temp': 0.54,
#   'max_temp': 3.93,
#   'the_temp': 3.805,
#   'wind_speed': 9.433908937771415,
#   'wind_direction': 249.49885635660405,
#   'air_pressure': 1008.0,
#   'humidity': 80,
#   'visibility': 15.713234709297701,
#   'predictability': 77},
#  {'id': 5179366167281664,
#   'weather_state_name': 'Thunder',
#   'weather_state_abbr': 't',
#   'wind_direction_compass': 'SW',
#   'created': '2022-01-06T02:22:07.546617Z',
#   'applicable_date': '2022-01-07',
#   'min_temp': 0.395,
#   'max_temp': 3.625,
#   'the_temp': 3.5949999999999998,
#   'wind_speed': 9.209878916113896,
#   'wind_direction': 227.76456063103726,
#   'air_pressure': 1012.0,
#   'humidity': 80,
#   'visibility': 10.74226517139903,
#   'predictability': 80},
#  {'id': 5541213202546688,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'WSW',
#   'created': '2022-01-05T23:22:11.064986Z',
#   'applicable_date': '2022-01-07',
#   'min_temp': 0.395,
#   'max_temp': 3.625,
#   'the_temp': 3.2800000000000002,
#   'wind_speed': 9.433571916113895,
#   'wind_direction': 248.83321107693303,
#   'air_pressure': 1008.5,
#   'humidity': 80,
#   'visibility': 13.829858625626342,
#   'predictability': 77},
#  {'id': 6209678288617472,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'WSW',
#   'created': '2022-01-05T20:22:09.840621Z',
#   'applicable_date': '2022-01-07',
#   'min_temp': 0.51,
#   'max_temp': 4.035,
#   'the_temp': 3.85,
#   'wind_speed': 9.30888357701954,
#   'wind_direction': 249.83349462388128,
#   'air_pressure': 1009.0,
#   'humidity': 77,
#   'visibility': 14.078407102521275,
#   'predictability': 77},
#  {'id': 6220340276494336,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'WSW',
#   'created': '2022-01-05T17:22:10.256427Z',
#   'applicable_date': '2022-01-07',
#   'min_temp': 0.515,
#   'max_temp': 4.1899999999999995,
#   'the_temp': 3.905,
#   'wind_speed': 9.36599147701954,
#   'wind_direction': 257.3073002134554,
#   'air_pressure': 1009.0,
#   'humidity': 77,
#   'visibility': 14.472356438399745,
#   'predictability': 77},
#  {'id': 4867755619647488,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'WSW',
#   'created': '2022-01-05T14:22:10.552342Z',
#   'applicable_date': '2022-01-07',
#   'min_temp': 0.255,
#   'max_temp': 4.26,
#   'the_temp': 3.96,
#   'wind_speed': 9.46251090483841,
#   'wind_direction': 250.83342272221,
#   'air_pressure': 1009.0,
#   'humidity': 76,
#   'visibility': 14.964793108247832,
#   'predictability': 73},
#  {'id': 6727215136899072,
#   'weather_state_name': 'Heavy Cloud',
#   'weather_state_abbr': 'hc',
#   'wind_direction_compass': 'WSW',
#   'created': '2022-01-05T11:22:09.763138Z',
#   'applicable_date': '2022-01-07',
#   'min_temp': 0.645,
#   'max_temp': 4.315,
#   'the_temp': 3.8600000000000003,
#   'wind_speed': 9.633300671505078,
#   'wind_direction': 257.6465848412478,
#   'air_pressure': 1009.0,
#   'humidity': 76,
#   'visibility': 14.092077268750497,
#   'predictability': 71},
#  {'id': 5918787736961024,
#   'weather_state_name': 'Light Rain',
#   'weather_state_abbr': 'lr',
#   'wind_direction_compass': 'WSW',
#   'created': '2022-01-05T08:22:11.964112Z',
#   'applicable_date': '2022-01-07',
#   'min_temp': 1.155,
#   'max_temp': 4.535,
#   'the_temp': 4.145,
#   'wind_speed': 9.684253088295025,
#   'wind_direction': 256.442560712877,
#   'air_pressure': 1010.5,
#   'humidity': 76,
#   'visibility': 14.539153841565259,
#   'predictability': 75},
#  {'id': 6475754532503552,
#   'weather_state_name': 'Light Rain',
#   'weather_state_abbr': 'lr',
#   'wind_direction_compass': 'WSW',
#   'created': '2022-01-05T05:22:09.878948Z',
#   'applicable_date': '2022-01-07',
#   'min_temp': 1.155,
#   'max_temp': 4.535,
#   'the_temp': 4.13,
#   'wind_speed': 9.721535254961692,
#   'wind_direction': 256.442560712877,
#   'air_pressure': 1010.5,
#   'humidity': 76,
#   'visibility': 15.894675097431003,
#   'predictability': 75},
#  {'id': 4974804290502656,
#   'weather_state_name': 'Light Rain',
#   'weather_state_abbr': 'lr',
#   'wind_direction_compass': 'SW',
#   'created': '2022-01-05T02:22:10.740481Z',
#   'applicable_date': '2022-01-07',
#   'min_temp': 0.61,
#   'max_temp': 4.275,
#   'the_temp': 4.135,
#   'wind_speed': 8.99949169729049,
#   'wind_direction': 231.70980256539548,
#   'air_pressure': 1013.0,
#   'humidity': 78,
#   'visibility': 11.157651813409688,
#   'predictability': 75},
#  {'id': 4728887113154560,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'WSW',
#   'created': '2022-01-04T23:22:12.864408Z',
#   'applicable_date': '2022-01-07',
#   'min_temp': 0.61,
#   'max_temp': 4.275,
#   'the_temp': 4.09,
#   'wind_speed': 9.282836163957157,
#   'wind_direction': 252.48909174321847,
#   'air_pressure': 1010.5,
#   'humidity': 77,
#   'visibility': 13.929899387576553,
#   'predictability': 73},
#  {'id': 4655549875486720,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'WSW',
#   'created': '2022-01-04T20:22:12.874367Z',
#   'applicable_date': '2022-01-07',
#   'min_temp': 0.59,
#   'max_temp': 4.16,
#   'the_temp': 3.925,
#   'wind_speed': 9.245139582040881,
#   'wind_direction': 246.5001904547795,
#   'air_pressure': 1010.5,
#   'humidity': 81,
#   'visibility': 14.532008072854529,
#   'predictability': 77},
#  {'id': 5741311568117760,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'WSW',
#   'created': '2022-01-04T17:22:12.858697Z',
#   'applicable_date': '2022-01-07',
#   'min_temp': 0.92,
#   'max_temp': 4.305,
#   'the_temp': 3.99,
#   'wind_speed': 9.568821448707547,
#   'wind_direction': 245.83335919427924,
#   'air_pressure': 1010.5,
#   'humidity': 81,
#   'visibility': 15.040911079296906,
#   'predictability': 77},
#  {'id': 5027395628171264,
#   'weather_state_name': 'Light Rain',
#   'weather_state_abbr': 'lr',
#   'wind_direction_compass': 'WSW',
#   'created': '2022-01-04T14:22:13.556734Z',
#   'applicable_date': '2022-01-07',
#   'min_temp': 1.385,
#   'max_temp': 4.52,
#   'the_temp': 4.05,
#   'wind_speed': 9.721678699077389,
#   'wind_direction': 256.08067499204685,
#   'air_pressure': 1011.0,
#   'humidity': 81,
#   'visibility': 16.154718941382328,
#   'predictability': 75},
#  {'id': 6635598518419456,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'WSW',
#   'created': '2022-01-04T11:22:12.688166Z',
#   'applicable_date': '2022-01-07',
#   'min_temp': 1.01,
#   'max_temp': 4.18,
#   'the_temp': 4.095,
#   'wind_speed': 9.079309399077388,
#   'wind_direction': 256.75583435350757,
#   'air_pressure': 1011.0,
#   'humidity': 82,
#   'visibility': 14.496589914897001,
#   'predictability': 73},
#  {'id': 6287221708554240,
#   'weather_state_name': 'Heavy Cloud',
#   'weather_state_abbr': 'hc',
#   'wind_direction_compass': 'WSW',
#   'created': '2022-01-04T08:22:14.255211Z',
#   'applicable_date': '2022-01-07',
#   'min_temp': 0.855,
#   'max_temp': 4.145,
#   'the_temp': 4.185,
#   'wind_speed': 8.973676296397041,
#   'wind_direction': 244.1713295412058,
#   'air_pressure': 1011.5,
#   'humidity': 79,
#   'visibility': 14.496589914897001,
#   'predictability': 71},
#  {'id': 5259041367392256,
#   'weather_state_name': 'Heavy Cloud',
#   'weather_state_abbr': 'hc',
#   'wind_direction_compass': 'WSW',
#   'created': '2022-01-04T05:22:12.998128Z',
#   'applicable_date': '2022-01-07',
#   'min_temp': 0.855,
#   'max_temp': 4.145,
#   'the_temp': 4.185,
#   'wind_speed': 8.973676296397041,
#   'wind_direction': 244.1713295412058,
#   'air_pressure': 1011.5,
#   'humidity': 79,
#   'visibility': 16.127067923327765,
#   'predictability': 71},
#  {'id': 5203464960344064,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'SW',
#   'created': '2022-01-04T02:22:13.563005Z',
#   'applicable_date': '2022-01-07',
#   'min_temp': 0.4,
#   'max_temp': 4.095,
#   'the_temp': 5.175,
#   'wind_speed': 10.430371497043929,
#   'wind_direction': 222.85873720573048,
#   'air_pressure': 1012.0,
#   'humidity': 80,
#   'visibility': 8.04986379543466,
#   'predictability': 73},
#  {'id': 5238287615655936,
#   'weather_state_name': 'Heavy Cloud',
#   'weather_state_abbr': 'hc',
#   'wind_direction_compass': 'WSW',
#   'created': '2022-01-03T23:22:17.049503Z',
#   'applicable_date': '2022-01-07',
#   'min_temp': 0.4,
#   'max_temp': 4.095,
#   'the_temp': 4.15,
#   'wind_speed': 8.93162839704393,
#   'wind_direction': 244.51207496626742,
#   'air_pressure': 1009.5,
#   'humidity': 79,
#   'visibility': 13.703720273602164,
#   'predictability': 71},
#  {'id': 5539385425526784,
#   'weather_state_name': 'Heavy Cloud',
#   'weather_state_abbr': 'hc',
#   'wind_direction_compass': 'WSW',
#   'created': '2022-01-03T20:22:17.156086Z',
#   'applicable_date': '2022-01-07',
#   'min_temp': 0.91,
#   'max_temp': 4.205,
#   'the_temp': 4.325,
#   'wind_speed': 9.122596015374214,
#   'wind_direction': 242.20760225505694,
#   'air_pressure': 1011.0,
#   'humidity': 77,
#   'visibility': 14.232507158196134,
#   'predictability': 71},
#  {'id': 5999149662076928,
#   'weather_state_name': 'Heavy Cloud',
#   'weather_state_abbr': 'hc',
#   'wind_direction_compass': 'WSW',
#   'created': '2022-01-03T17:22:16.473674Z',
#   'applicable_date': '2022-01-07',
#   'min_temp': 0.715,
#   'max_temp': 4.045,
#   'the_temp': 4.335,
#   'wind_speed': 9.021190748707548,
#   'wind_direction': 241.87295853159122,
#   'air_pressure': 1011.0,
#   'humidity': 78,
#   'visibility': 14.59010627932872,
#   'predictability': 71},
#  {'id': 6690422567993344,
#   'weather_state_name': 'Light Cloud',
#   'weather_state_abbr': 'lc',
#   'wind_direction_compass': 'WSW',
#   'created': '2022-01-03T14:22:18.379266Z',
#   'applicable_date': '2022-01-07',
#   'min_temp': 0.11999999999999997,
#   'max_temp': 3.8549999999999995,
#   'the_temp': 4.145,
#   'wind_speed': 9.31240648342745,
#   'wind_direction': 243.18781768037604,
#   'air_pressure': 1010.0,
#   'humidity': 79,
#   'visibility': 15.7598375487155,
#   'predictability': 70},
#  {'id': 6209153765736448,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'WSW',
#   'created': '2022-01-03T11:22:25.131449Z',
#   'applicable_date': '2022-01-07',
#   'min_temp': 0.30000000000000004,
#   'max_temp': 3.995,
#   'the_temp': 4.185,
#   'wind_speed': 9.440129883427451,
#   'wind_direction': 242.1844309326289,
#   'air_pressure': 1008.5,
#   'humidity': 80,
#   'visibility': 13.402044559770937,
#   'predictability': 73},
#  {'id': 5024948939653120,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'WSW',
#   'created': '2022-01-03T08:22:15.658363Z',
#   'applicable_date': '2022-01-07',
#   'min_temp': 0.72,
#   'max_temp': 4.23,
#   'the_temp': 4.43,
#   'wind_speed': 9.851063281333015,
#   'wind_direction': 247.16668312112554,
#   'air_pressure': 1007.0,
#   'humidity': 77,
#   'visibility': 13.830479996818578,
#   'predictability': 77},
#  {'id': 6619775590465536,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'WSW',
#   'created': '2022-01-03T05:22:17.688396Z',
#   'applicable_date': '2022-01-07',
#   'min_temp': 0.72,
#   'max_temp': 4.23,
#   'the_temp': 4.390000000000001,
#   'wind_speed': 9.813781114666348,
#   'wind_direction': 247.16668312112554,
#   'air_pressure': 1007.5,
#   'humidity': 77,
#   'visibility': 15.060173586256262,
#   'predictability': 77},
#  {'id': 4772061265264640,
#   'weather_state_name': 'Light Rain',
#   'weather_state_abbr': 'lr',
#   'wind_direction_compass': 'SW',
#   'created': '2022-01-03T02:22:16.460950Z',
#   'applicable_date': '2022-01-07',
#   'min_temp': 0.85,
#   'max_temp': 4.305,
#   'the_temp': 5.335,
#   'wind_speed': 11.18938016241682,
#   'wind_direction': 219.0821532488186,
#   'air_pressure': 1008.0,
#   'humidity': 88,
#   'visibility': 7.1979638908772765,
#   'predictability': 75},
#  {'id': 4788408984535040,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'SW',
#   'created': '2022-01-02T23:22:19.229739Z',
#   'applicable_date': '2022-01-07',
#   'min_temp': 0.85,
#   'max_temp': 4.305,
#   'the_temp': 3.01,
#   'wind_speed': 8.306105543625229,
#   'wind_direction': 228.0,
#   'air_pressure': 1008.0,
#   'humidity': 89,
#   'visibility': 9.999726596675416,
#   'predictability': 73},
#  {'id': 4567631358066688,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'SW',
#   'created': '2022-01-02T20:22:18.873905Z',
#   'applicable_date': '2022-01-07',
#   'min_temp': 1.52,
#   'max_temp': 4.91,
#   'the_temp': 4.77,
#   'wind_speed': 8.554654020520163,
#   'wind_direction': 230.99999999999997,
#   'air_pressure': 1014.0,
#   'humidity': 81,
#   'visibility': 9.999726596675416,
#   'predictability': 73},
#  {'id': 6653857095483392,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'SW',
#   'created': '2022-01-02T17:22:19.757971Z',
#   'applicable_date': '2022-01-07',
#   'min_temp': 1.5350000000000001,
#   'max_temp': 4.425,
#   'the_temp': 4.77,
#   'wind_speed': 8.884654020520163,
#   'wind_direction': 233.5,
#   'air_pressure': 1014.0,
#   'humidity': 81,
#   'visibility': 9.999726596675416,
#   'predictability': 73},
#  {'id': 5680875204247552,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'WSW',
#   'created': '2022-01-02T14:22:19.273629Z',
#   'applicable_date': '2022-01-07',
#   'min_temp': 1.03,
#   'max_temp': 3.76,
#   'the_temp': 3.56,
#   'wind_speed': 9.080385946074923,
#   'wind_direction': 258.5,
#   'air_pressure': 1009.0,
#   'humidity': 76,
#   'visibility': 9.999726596675416,
#   'predictability': 77},
#  {'id': 6317371875655680,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'WSW',
#   'created': '2022-01-02T11:22:19.749422Z',
#   'applicable_date': '2022-01-07',
#   'min_temp': 0.035,
#   'max_temp': 3.9349999999999996,
#   'the_temp': 3.56,
#   'wind_speed': 8.445385946074921,
#   'wind_direction': 251.0,
#   'air_pressure': 1009.0,
#   'humidity': 77,
#   'visibility': 9.86116082080649,
#   'predictability': 77},
#  {'id': 6400041708158976,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'SW',
#   'created': '2022-01-02T08:22:18.863403Z',
#   'applicable_date': '2022-01-07',
#   'min_temp': 0.26,
#   'max_temp': 4.455,
#   'the_temp': 3.68,
#   'wind_speed': 8.827529229300882,
#   'wind_direction': 225.0,
#   'air_pressure': 1008.0,
#   'humidity': 79,
#   'visibility': 9.86116082080649,
#   'predictability': 77},
#  {'id': 4859202125168640,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'SW',
#   'created': '2022-01-02T05:22:19.087694Z',
#   'applicable_date': '2022-01-07',
#   'min_temp': 0.26,
#   'max_temp': 4.455,
#   'the_temp': 3.68,
#   'wind_speed': 8.827529229300882,
#   'wind_direction': 225.0,
#   'air_pressure': 1008.0,
#   'humidity': 79,
#   'visibility': 9.86116082080649,
#   'predictability': 77},
#  {'id': 5435891410534400,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'W',
#   'created': '2022-01-02T02:22:19.465358Z',
#   'applicable_date': '2022-01-07',
#   'min_temp': 0.83,
#   'max_temp': 4.805,
#   'the_temp': 4.17,
#   'wind_speed': 9.482390240992604,
#   'wind_direction': 265.0,
#   'air_pressure': 1010.0,
#   'humidity': 80,
#   'visibility': 9.999726596675416,
#   'predictability': 77},
#  {'id': 6209431059562496,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'W',
#   'created': '2022-01-01T23:22:22.451597Z',
#   'applicable_date': '2022-01-07',
#   'min_temp': 0.83,
#   'max_temp': 4.805,
#   'the_temp': 4.17,
#   'wind_speed': 9.482390240992604,
#   'wind_direction': 265.0,
#   'air_pressure': 1010.0,
#   'humidity': 80,
#   'visibility': 9.999726596675416,
#   'predictability': 77},
#  {'id': 4773301604843520,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'WNW',
#   'created': '2022-01-01T20:22:22.088973Z',
#   'applicable_date': '2022-01-07',
#   'min_temp': 0.54,
#   'max_temp': 4.035,
#   'the_temp': 3.14,
#   'wind_speed': 8.224113576712002,
#   'wind_direction': 284.5,
#   'air_pressure': 1010.0,
#   'humidity': 88,
#   'visibility': 9.999726596675416,
#   'predictability': 77},
#  {'id': 4973679009071104,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'WNW',
#   'created': '2022-01-01T17:22:22.958702Z',
#   'applicable_date': '2022-01-07',
#   'min_temp': 0.445,
#   'max_temp': 3.695,
#   'the_temp': 3.14,
#   'wind_speed': 8.264113576712003,
#   'wind_direction': 297.5,
#   'air_pressure': 1010.0,
#   'humidity': 89,
#   'visibility': 9.999726596675416,
#   'predictability': 77},
#  {'id': 5981260250873856,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'NW',
#   'created': '2022-01-01T14:22:21.875060Z',
#   'applicable_date': '2022-01-07',
#   'min_temp': -0.2,
#   'max_temp': 3.145,
#   'the_temp': 2.15,
#   'wind_speed': 8.428776942654896,
#   'wind_direction': 314.5,
#   'air_pressure': 1009.0,
#   'humidity': 90,
#   'visibility': 9.999726596675416,
#   'predictability': 77},
#  {'id': 5667040175063040,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'SSW',
#   'created': '2022-01-01T11:22:23.055324Z',
#   'applicable_date': '2022-01-07',
#   'min_temp': -1.49,
#   'max_temp': 3.635,
#   'the_temp': 2.15,
#   'wind_speed': 7.253776942654895,
#   'wind_direction': 191.99999999999997,
#   'air_pressure': 1009.0,
#   'humidity': 90,
#   'visibility': 9.999726596675416,
#   'predictability': 77},
#  {'id': 4963517116448768,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'S',
#   'created': '2022-01-01T08:22:21.870354Z',
#   'applicable_date': '2022-01-07',
#   'min_temp': 0.07500000000000018,
#   'max_temp': 4.775,
#   'the_temp': 4.39,
#   'wind_speed': 7.648347649725602,
#   'wind_direction': 180.0,
#   'air_pressure': 1015.0,
#   'humidity': 89,
#   'visibility': 9.999726596675416,
#   'predictability': 77},
#  {'id': 5700661447491584,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'S',
#   'created': '2022-01-01T05:22:21.773336Z',
#   'applicable_date': '2022-01-07',
#   'min_temp': 0.07500000000000018,
#   'max_temp': 4.775,
#   'the_temp': 4.39,
#   'wind_speed': 7.648347649725602,
#   'wind_direction': 180.0,
#   'air_pressure': 1015.0,
#   'humidity': 89,
#   'visibility': 9.999726596675416,
#   'predictability': 77},
#  {'id': 6180678669434880,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'WSW',
#   'created': '2022-01-01T02:22:22.287222Z',
#   'applicable_date': '2022-01-07',
#   'min_temp': 0.595,
#   'max_temp': 11.07,
#   'the_temp': 5.05,
#   'wind_speed': 8.629944325141176,
#   'wind_direction': 256.5,
#   'air_pressure': 1025.0,
#   'humidity': 74,
#   'visibility': 9.999726596675416,
#   'predictability': 77},
#  {'id': 5820318699487232,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'WSW',
#   'created': '2021-12-31T23:22:25.158995Z',
#   'applicable_date': '2022-01-07',
#   'min_temp': 0.595,
#   'max_temp': 11.07,
#   'the_temp': 5.05,
#   'wind_speed': 8.629944325141176,
#   'wind_direction': 256.5,
#   'air_pressure': 1025.0,
#   'humidity': 74,
#   'visibility': 9.999726596675416,
#   'predictability': 77},
#  {'id': 4584182215868416,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'WSW',
#   'created': '2021-12-31T20:22:25.136167Z',
#   'applicable_date': '2022-01-07',
#   'min_temp': 0.615,
#   'max_temp': 11.215,
#   'the_temp': 5.13,
#   'wind_speed': 8.570914061878629,
#   'wind_direction': 253.5,
#   'air_pressure': 1012.0,
#   'humidity': 75,
#   'visibility': 9.999726596675416,
#   'predictability': 77},
#  {'id': 5205406285561856,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'WSW',
#   'created': '2021-12-31T17:22:25.178119Z',
#   'applicable_date': '2022-01-07',
#   'min_temp': 2.565,
#   'max_temp': 6.890000000000001,
#   'the_temp': 5.13,
#   'wind_speed': 9.49591406187863,
#   'wind_direction': 255.5,
#   'air_pressure': 1012.0,
#   'humidity': 85,
#   'visibility': 9.999726596675416,
#   'predictability': 73},
#  {'id': 6144198794280960,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'WSW',
#   'created': '2021-12-31T14:22:25.538990Z',
#   'applicable_date': '2022-01-07',
#   'min_temp': 3.06,
#   'max_temp': 6.404999999999999,
#   'the_temp': 5.18,
#   'wind_speed': 9.688539131472202,
#   'wind_direction': 253.0,
#   'air_pressure': 1017.0,
#   'humidity': 84,
#   'visibility': 9.999726596675416,
#   'predictability': 73},
#  {'id': 4893150553309184,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'WSW',
#   'created': '2021-12-31T11:22:25.539189Z',
#   'applicable_date': '2022-01-07',
#   'min_temp': 3.62,
#   'max_temp': 7.245,
#   'the_temp': 5.18,
#   'wind_speed': 11.253539131472202,
#   'wind_direction': 252.5,
#   'air_pressure': 1017.0,
#   'humidity': 83,
#   'visibility': 9.999726596675416,
#   'predictability': 77},
#  {'id': 5511119037792256,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'WSW',
#   'created': '2021-12-31T08:22:24.973589Z',
#   'applicable_date': '2022-01-07',
#   'min_temp': 3.6550000000000002,
#   'max_temp': 7.890000000000001,
#   'the_temp': 5.6,
#   'wind_speed': 11.613934422969857,
#   'wind_direction': 247.0,
#   'air_pressure': 1011.0,
#   'humidity': 82,
#   'visibility': 9.999726596675416,
#   'predictability': 77},
#  {'id': 6403232197771264,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'WSW',
#   'created': '2021-12-31T05:22:25.666238Z',
#   'applicable_date': '2022-01-07',
#   'min_temp': 3.6550000000000002,
#   'max_temp': 7.890000000000001,
#   'the_temp': 5.6,
#   'wind_speed': 11.613934422969857,
#   'wind_direction': 247.0,
#   'air_pressure': 1011.0,
#   'humidity': 82,
#   'visibility': 9.999726596675416,
#   'predictability': 77},
#  {'id': 6436192649216000,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'WSW',
#   'created': '2021-12-31T02:22:24.867051Z',
#   'applicable_date': '2022-01-07',
#   'min_temp': 4.01,
#   'max_temp': 10.82,
#   'the_temp': 8.92,
#   'wind_speed': 5.399715660542432,
#   'wind_direction': 238.0,
#   'air_pressure': 1012.0,
#   'humidity': 76,
#   'visibility': None,
#   'predictability': 77},
#  {'id': 5215357120806912,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'WSW',
#   'created': '2021-12-30T23:22:28.683225Z',
#   'applicable_date': '2022-01-07',
#   'min_temp': 4.01,
#   'max_temp': 10.82,
#   'the_temp': 8.92,
#   'wind_speed': 5.399715660542432,
#   'wind_direction': 238.0,
#   'air_pressure': 1012.0,
#   'humidity': 76,
#   'visibility': None,
#   'predictability': 77},
#  {'id': 6232093899096064,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'SW',
#   'created': '2021-12-30T20:22:27.954999Z',
#   'applicable_date': '2022-01-07',
#   'min_temp': 3.37,
#   'max_temp': 9.78,
#   'the_temp': 6.35,
#   'wind_speed': 5.325151117473952,
#   'wind_direction': 220.99999999999997,
#   'air_pressure': 1013.0,
#   'humidity': 72,
#   'visibility': None,
#   'predictability': 77},
#  {'id': 4992303161671680,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'SW',
#   'created': '2021-12-30T17:22:28.549070Z',
#   'applicable_date': '2022-01-07',
#   'min_temp': 3.37,
#   'max_temp': 9.78,
#   'the_temp': 6.35,
#   'wind_speed': 5.325151117473952,
#   'wind_direction': 220.99999999999997,
#   'air_pressure': 1013.0,
#   'humidity': 72,
#   'visibility': None,
#   'predictability': 77},
#  {'id': 5575292803350528,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'WSW',
#   'created': '2021-12-30T14:22:28.554140Z',
#   'applicable_date': '2022-01-07',
#   'min_temp': 4.48,
#   'max_temp': 9.35,
#   'the_temp': 9.35,
#   'wind_speed': 5.070388928656645,
#   'wind_direction': 242.0,
#   'air_pressure': 1011.0,
#   'humidity': 87,
#   'visibility': None,
#   'predictability': 77},
#  {'id': 5129392947724288,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'WSW',
#   'created': '2021-12-30T11:22:28.076377Z',
#   'applicable_date': '2022-01-07',
#   'min_temp': 4.48,
#   'max_temp': 9.35,
#   'the_temp': 9.35,
#   'wind_speed': 5.070388928656645,
#   'wind_direction': 242.0,
#   'air_pressure': 1011.0,
#   'humidity': 87,
#   'visibility': None,
#   'predictability': 77},
#  {'id': 4575239087325184,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'SW',
#   'created': '2021-12-30T08:22:28.454239Z',
#   'applicable_date': '2022-01-07',
#   'min_temp': 3.32,
#   'max_temp': 7.79,
#   'the_temp': 7.79,
#   'wind_speed': 6.139147379304859,
#   'wind_direction': 215.99999999999997,
#   'air_pressure': 1009.0,
#   'humidity': 78,
#   'visibility': None,
#   'predictability': 77},
#  {'id': 6213205396291584,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'SW',
#   'created': '2021-12-30T05:22:28.468283Z',
#   'applicable_date': '2022-01-07',
#   'min_temp': 3.32,
#   'max_temp': 7.79,
#   'the_temp': 7.79,
#   'wind_speed': 6.139147379304859,
#   'wind_direction': 215.99999999999997,
#   'air_pressure': 1009.0,
#   'humidity': 78,
#   'visibility': None,
#   'predictability': 77},
#  {'id': 6583274743791616,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'SW',
#   'created': '2021-12-30T02:22:28.550435Z',
#   'applicable_date': '2022-01-07',
#   'min_temp': 1.84,
#   'max_temp': 6.04,
#   'the_temp': 6.04,
#   'wind_speed': 5.859530342798059,
#   'wind_direction': 213.99999999999997,
#   'air_pressure': 1012.0,
#   'humidity': 93,
#   'visibility': None,
#   'predictability': 77}]

# %% [markdown]
# Much easier to read but still a very long list. The value we want is 'the_temp' but we can see there are many recordings over the course of the day. We can build a for loop to get the average:

# %%
count_temp = 0
n = 0

for result in weather_list:
    count_temp += result['the_temp']
    n += 1

avg_temp = count_temp / n
print(avg_temp)
# Out:
# 4.621875000000003

# %% [markdown]
# Great! Let's put all that together and search average temperatures for three cities. Note, as the docs specify we should make only one request a minute we are using _time.sleep(60)_ to make the script wait for 60 seconds between calls. This does mean it will take > 6 minutes to run our script. Make a coffee.

# %%
output = []

city_list = ["London", "New York", "Beijing"]
day = "2022/01/07"

for city in city_list:
    # get location
    r = location_generator(city)
    response_list = r.json()
    time.sleep(60)
    
    # get weather 
    w = weather_generator(response_list[0]["woeid"], day)
    weather_list = w.json()
    time.sleep(60)
    
    # get average temp
    count_temp = 0
    n = 0

    for result in weather_list:
        count_temp += result['the_temp']
        n += 1

    avg_temp = count_temp / n
    avg_temp = round(avg_temp, 2)
    
    print(f"The average temp in {city} on {day} was {avg_temp}")
    
    output.append({"City": city, "Date": day, "Avg Temp": avg_temp})
# Out:
# The average temp in London on 2022/01/07 was 6.05
# The average temp in New York on 2022/01/07 was 2.61
# The average temp in Beijing on 2022/01/07 was 2.45

# %% [markdown]
# Now we have our data we can move it into something more familiar like _pandas:_

# %%
cityfacts_df = pd.DataFrame(output) 
cityfacts_df.head()
# Out:
#        City        Date  Avg Temp
# 0    London  2022/01/07      6.05
# 1  New York  2022/01/07      2.61
# 2   Beijing  2022/01/07      2.45

# %% [markdown]
# And that's it! Hopefully you can see that the use of _json_ makes the output much easier to work with. Remember this in the IMA!
